# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
SST_HOME='drive/My Drive/Colab Notebooks/Erisk2019/'

# %%
import requests
import numpy as np



URL_PREFIX="http://erisk.irlab.org/challenge-t1e/results/"
URL_PREFIX_RANKINGS="http://erisk.irlab.org/challenge-t1e/retrieve/"  

def penalty(delay):
    p = 0.0078
    pen = -1.0 + 2.0/(1+np.exp(-p*(delay-1)))
    return(pen)
    


def read_qrels(qrels_file):
    qrels={}
    f = open(qrels_file, 'r')
    for line in f:
        datos=line.split()
        qrels[ datos[0] ] = int(datos[1])
    f.close()
    print("\n"+str(len(qrels))+ " lines read in qrels file!\n\n")
    return(qrels)


def read_run(team_token, run_number):
    GET_REQUEST_STRING=URL_PREFIX+team_token+"/"+run_number
    print("Connecting to..."+GET_REQUEST_STRING)
    r=requests.get(GET_REQUEST_STRING)
    
    if (r.status_code==requests.codes.ok):
        print("Response..."+str(r.status_code)+" OK")
    
    
    run_results=r.json()
    print(str(len(run_results))+ " entries in the run ")
    
    return(run_results)

def n_pos(qrels):
    total_pos = 0
    
    for key in qrels:
        total_pos += qrels[key]

    return(total_pos)


def eval_performance(run_results,qrels):
    
    print("===================================================")
    print("DECISION-BASED EVALUATION:")     

    
    total_pos=n_pos(qrels)
        
    true_pos = 0
    true_neg = 0
    false_pos = 0
    false_neg = 0
    erdes5 = np.zeros(len(run_results))
    erdes50 = np.zeros(len(run_results))
    ierdes = 0
    latency_tps = list()
    penalty_tps = list()
   
    
    for r in run_results:
        
        try:
            
            if ( qrels[ r['nick']   ] ==  r['decision'] ):
                if ( r['decision'] == 1 ): 
                    true_pos+=1
                    erdes5[ierdes]=1.0 - (1.0/(1.0+np.exp( (r['sequence']+1) - 5.0)))
                    erdes50[ierdes]=1.0 - (1.0/(1.0+np.exp( (r['sequence']+1) - 50.0)))
                    latency_tps.append(r['sequence']+1)
                    penalty_tps.append(penalty(r['sequence']+1))
                else:
                    true_neg+=1
                    erdes5[ierdes]=0
                    erdes50[ierdes]=0
            else:
                if ( r['decision'] == 1 ): 
                    false_pos+=1
                    erdes5[ierdes]=float(total_pos)/float(len(qrels))
                    erdes50[ierdes]=float(total_pos)/float(len(qrels))
                else:
                    false_neg+=1
                    erdes5[ierdes]=1
                    erdes50[ierdes]=1
                
        except KeyError:
            print("User does not appear in the qrels:"+r['nick'])
        
        ierdes+=1
    
    if ( true_pos == 0 ):
        precision = 0
        recall = 0
        F1 = 0
    else:
        precision = float(true_pos) / float(true_pos+false_pos)    
        recall = float(true_pos) / float(total_pos)   
        F1 = 2 * (precision * recall) / (precision + recall)
        
    speed = 1-np.median(np.array(penalty_tps))    
        
    print("Precision:"+str(precision))
    print("Recall:"+str(recall))
    print("F1:"+str(F1))
    print("ERDE_5:"+str(np.mean(erdes5)))
    print("ERDE_50:"+str(np.mean(erdes50)))
    print("Median latency TPs:"+str(np.median(np.array(latency_tps))))
    print("Median penalty TPs:"+str(np.median(np.array(penalty_tps))))
    print("Speed:"+str(speed))
    print("latency-weighted F1:"+str(F1*speed))
    
    
def compute_ideal_dcg_vector(qrels):
    ideal_dcg_vector=np.zeros(len(qrels))
    total_pos=n_pos(qrels)
    
    for i in range(len(qrels)):
        if i < total_pos:
            if (i==0):
                ideal_dcg_vector[i]=1.0
            else:
                ideal_dcg_vector[i]= ideal_dcg_vector[i-1] + 1.0/np.log2(i+1)
        else:
            ideal_dcg_vector[i]= ideal_dcg_vector[i-1]
        
    return(ideal_dcg_vector)
    
    
def eval_performance_rank_based(team_token, run_number, qrels):
    GET_REQUEST_STRING=URL_PREFIX_RANKINGS+team_token+"/"+run_number+"/"
    
    ideal_dcg_vector=compute_ideal_dcg_vector(qrels)
   
    print("===================================================")
    print("RANK-BASED EVALUATION:")     
    
    k=10
    
    ranks_at=[1,50,100,500,1000,2000]
    
   
    for rank in ranks_at:
        r=requests.get(GET_REQUEST_STRING+str(rank))
          
      #  if(len(r.json())==0): 
      #      break
        
        print("Analizing ranking at round "+str(rank))
        print("Rank size:"+str(len(r.json())))
        
        run_results_rank=r.json()
 
        dcg_vector=np.zeros(len(qrels))
        rels_topk=0
        
        i=0
        for r in run_results_rank:
            dcg_vector[i] = qrels[ r['nick'] ]
            
            if i>1:
                dcg_vector[i]=dcg_vector[i]/np.log2(i+1)
            if i>0:
                dcg_vector[i]=dcg_vector[i]+dcg_vector[i-1]
            if i<k:
                rels_topk+= qrels[ r['nick'] ]
        
            i+=1    
    
        ndcg_vector = dcg_vector/ideal_dcg_vector
        
        print("P@10:"+str(float(rels_topk)/10.0))
        print("NDCG@10:"+str(ndcg_vector[9]))
        print("NDCG@100:"+str(ndcg_vector[99]))

        print("===================================================")
        
        
    
    run_results=r.json()
    print(run_results)
    print(str(len(run_results))+ " entries in the run ")
    
   



# parameters.... team_token   (string), 
#                run_number (integer - 0,1,2,... -)
#                gt_file (string)..path to the ground truth file
   
   
def eval_run(team_token, run_number, gt_file):
    
    qrels=read_qrels(gt_file)  
    run_results=read_run(team_token,str(run_number))
    eval_performance(run_results,qrels)
    eval_performance_rank_based(team_token,str(run_number),qrels)

# %%
# !ls 'drive/My Drive/Colab Notebooks/Erisk2019/datas/ground_truth/T1_erisk_golden_truth.txt'
# Out:
# 'drive/My Drive/Colab Notebooks/Erisk2019/datas/ground_truth/T1_erisk_golden_truth.txt'

# %%
TEAM_TOKEN = "1f4c93c4e114d6e72706c31901101db7vv"
# ftp://erisk.irlab.org/groundstruth/groundstruth/
GT_PATH = 'drive/My Drive/Colab Notebooks/Erisk2019/datas/ground_truth/T1_erisk_golden_truth.txt'

# %%
with open(SST_HOME+"evaluation2.txt", "w") as results_file:
  for run_number in [0, 1, 2, 3, 4]:
    print("MODEL NUMBER: {}".format(run_number + 1))
    results = eval_run(TEAM_TOKEN, run_number, GT_PATH)
    print("\n")
    results_file.write(str(results))
# Out:
# MODEL NUMBER: 1
#
# 815 lines read in qrels file!
#
#
# Connecting to...http://erisk.irlab.org/challenge-t1e/results/1f4c93c4e114d6e72706c31901101db7vv/0
# Response...200 OK
# 815 entries in the run
# ===================================================
# DECISION-BASED EVALUATION:
# Precision:0.16030534351145037
# Recall:0.2876712328767123
# F1:0.20588235294117646
# ERDE_5:0.07635640631337454
# ERDE_50:0.07589295795852309
# Median latency TPs:1.0
# Median penalty TPs:0.0
# Speed:1.0
# latency-weighted F1:0.20588235294117646
# ===================================================
# RANK-BASED EVALUATION:
# Analizing ranking at round 1
# Rank size:815
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.03898351729997353
# ===================================================
# Analizing ranking at round 50
# Rank size:815
# P@10:0.3
# NDCG@10:0.4055441962681695
# NDCG@100:0.24903052229443132
# ===================================================
# Analizing ranking at round 100
# Rank size:815
# P@10:0.4
# NDCG@10:0.28642248913872886
# NDCG@100:0.26113662255172154
# ===================================================
# Analizing ranking at round 500
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# Analizing ranking at round 1000
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# Analizing ranking at round 2000
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# []
# 0 entries in the run
#
#
# MODEL NUMBER: 2
#
# 815 lines read in qrels file!
#
#
# Connecting to...http://erisk.irlab.org/challenge-t1e/results/1f4c93c4e114d6e72706c31901101db7vv/1
# Response...200 OK
# 815 entries in the run
# ===================================================
# DECISION-BASED EVALUATION:
# Precision:0.09033613445378151
# Recall:0.589041095890411
# F1:0.15664845173041894
# ERDE_5:0.11886438005916099
# ERDE_50:0.0843976062328278
# Median latency TPs:8.0
# Median penalty TPs:0.027293219882254416
# Speed:0.9727067801177456
# latency-weighted F1:0.1523730110931259
# ===================================================
# RANK-BASED EVALUATION:
# Analizing ranking at round 1
# Rank size:815
# P@10:0.1
# NDCG@10:0.05729000096767666
# NDCG@100:0.13501632833720917
# ===================================================
# Analizing ranking at round 50
# Rank size:815
# P@10:0.1
# NDCG@10:0.05729000096767666
# NDCG@100:0.14581329713501295
# ===================================================
# Analizing ranking at round 100
# Rank size:815
# P@10:0.1
# NDCG@10:0.05729000096767666
# NDCG@100:0.1365726242309245
# ===================================================
# Analizing ranking at round 500
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# Analizing ranking at round 1000
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# Analizing ranking at round 2000
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# []
# 0 entries in the run
#
#
# MODEL NUMBER: 3
#
# 815 lines read in qrels file!
#
#
# Connecting to...http://erisk.irlab.org/challenge-t1e/results/1f4c93c4e114d6e72706c31901101db7vv/2
# Response...200 OK
# 815 entries in the run
# ===================================================
# DECISION-BASED EVALUATION:
# Precision:0.07740585774058577
# Recall:0.5068493150684932
# F1:0.13430127041742287
# ERDE_5:0.13801543687522663
# ERDE_50:0.12194050513140492
# Median latency TPs:77.0
# Median penalty TPs:0.288014675005309
# Speed:0.711985324994691
# latency-weighted F1:0.09562053366534871
# ===================================================
# RANK-BASED EVALUATION:
# Analizing ranking at round 1
# Rank size:815
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.03850693239584506
# ===================================================
# Analizing ranking at round 50
# Rank size:815
# P@10:0.1
# NDCG@10:0.06343775459021642
# NDCG@100:0.1594103066292053
# ===================================================
# Analizing ranking at round 100
# Rank size:815
# P@10:0.2
# NDCG@10:0.12782810266318784
# NDCG@100:0.10444841814797806
# ===================================================
# Analizing ranking at round 500
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# Analizing ranking at round 1000
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# Analizing ranking at round 2000
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# []
# 0 entries in the run
#
#
# MODEL NUMBER: 4
#
# 815 lines read in qrels file!
#
#
# Connecting to...http://erisk.irlab.org/challenge-t1e/results/1f4c93c4e114d6e72706c31901101db7vv/3
# Response...200 OK
# 815 entries in the run
# ===================================================
# DECISION-BASED EVALUATION:
# Precision:0.09171974522292993
# Recall:0.9863013698630136
# F1:0.1678321678321678
# ERDE_5:0.0901255957514972
# ERDE_50:0.07958748917912085
# Median latency TPs:1.0
# Median penalty TPs:0.0
# Speed:1.0
# latency-weighted F1:0.1678321678321678
# ===================================================
# RANK-BASED EVALUATION:
# Analizing ranking at round 1
# Rank size:815
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.08245113463951013
# ===================================================
# Analizing ranking at round 50
# Rank size:815
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.09542513911131552
# ===================================================
# Analizing ranking at round 100
# Rank size:815
# P@10:0.3
# NDCG@10:0.19435097590153655
# NDCG@100:0.20476371314647143
# ===================================================
# Analizing ranking at round 500
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# Analizing ranking at round 1000
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# Analizing ranking at round 2000
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# []
# 0 entries in the run
#
#
# MODEL NUMBER: 5
#
# 815 lines read in qrels file!
#
#
# Connecting to...http://erisk.irlab.org/challenge-t1e/results/1f4c93c4e114d6e72706c31901101db7vv/4
# Response...200 OK
# 815 entries in the run
# ===================================================
# DECISION-BASED EVALUATION:
# Precision:0.10264900662251655
# Recall:0.4246575342465753
# F1:0.16533333333333333
# ERDE_5:0.10047023157734249
# ERDE_50:0.0813255367890927
# Median latency TPs:5.0
# Median penalty TPs:0.015598734651173896
# Speed:0.9844012653488261
# latency-weighted F1:0.16275434253767257
# ===================================================
# RANK-BASED EVALUATION:
# Analizing ranking at round 1
# Rank size:815
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0799759166425321
# ===================================================
# Analizing ranking at round 50
# Rank size:815
# P@10:0.2
# NDCG@10:0.3103875643828448
# NDCG@100:0.15625049256998796
# ===================================================
# Analizing ranking at round 100
# Rank size:815
# P@10:0.2
# NDCG@10:0.16294758424241468
# NDCG@100:0.13884881960356402
# ===================================================
# Analizing ranking at round 500
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# Analizing ranking at round 1000
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# Analizing ranking at round 2000
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# []
# 0 entries in the run

# %%
for run_number in [0, 1, 2, 3, 4]:
  print("MODEL NUMBER: {}".format(run_number + 1))
  results = eval_run(TEAM_TOKEN, run_number, GT_PATH)
  print("\n")
# Out:
# MODEL NUMBER: 1
#
# 815 lines read in qrels file!
#
#
# Connecting to...http://erisk.irlab.org/challenge-t1e/results/1f4c93c4e114d6e72706c31901101db7vv/0
# Response...200 OK
# 815 entries in the run
# ===================================================
# DECISION-BASED EVALUATION:
# Precision:0.16030534351145037
# Recall:0.2876712328767123
# F1:0.20588235294117646
# ERDE_5:0.07635640631337454
# ERDE_50:0.07589295795852309
# Median latency TPs:1.0
# Median penalty TPs:0.0
# Speed:1.0
# latency-weighted F1:0.20588235294117646
# ===================================================
# RANK-BASED EVALUATION:
# Analizing ranking at round 1
# Rank size:815
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.03898351729997353
# ===================================================
# Analizing ranking at round 50
# Rank size:815
# P@10:0.3
# NDCG@10:0.4055441962681695
# NDCG@100:0.24903052229443132
# ===================================================
# Analizing ranking at round 100
# Rank size:815
# P@10:0.4
# NDCG@10:0.28642248913872886
# NDCG@100:0.26113662255172154
# ===================================================
# Analizing ranking at round 500
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# Analizing ranking at round 1000
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# Analizing ranking at round 2000
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# []
# 0 entries in the run
#
#
# MODEL NUMBER: 2
#
# 815 lines read in qrels file!
#
#
# Connecting to...http://erisk.irlab.org/challenge-t1e/results/1f4c93c4e114d6e72706c31901101db7vv/1
# Response...200 OK
# 815 entries in the run
# ===================================================
# DECISION-BASED EVALUATION:
# Precision:0.09033613445378151
# Recall:0.589041095890411
# F1:0.15664845173041894
# ERDE_5:0.11886438005916099
# ERDE_50:0.0843976062328278
# Median latency TPs:8.0
# Median penalty TPs:0.027293219882254416
# Speed:0.9727067801177456
# latency-weighted F1:0.1523730110931259
# ===================================================
# RANK-BASED EVALUATION:
# Analizing ranking at round 1
# Rank size:815
# P@10:0.1
# NDCG@10:0.05729000096767666
# NDCG@100:0.13501632833720917
# ===================================================
# Analizing ranking at round 50
# Rank size:815
# P@10:0.1
# NDCG@10:0.05729000096767666
# NDCG@100:0.14581329713501295
# ===================================================
# Analizing ranking at round 100
# Rank size:815
# P@10:0.1
# NDCG@10:0.05729000096767666
# NDCG@100:0.1365726242309245
# ===================================================
# Analizing ranking at round 500
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# Analizing ranking at round 1000
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# Analizing ranking at round 2000
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# []
# 0 entries in the run
#
#
# MODEL NUMBER: 3
#
# 815 lines read in qrels file!
#
#
# Connecting to...http://erisk.irlab.org/challenge-t1e/results/1f4c93c4e114d6e72706c31901101db7vv/2
# Response...200 OK
# 815 entries in the run
# ===================================================
# DECISION-BASED EVALUATION:
# Precision:0.07740585774058577
# Recall:0.5068493150684932
# F1:0.13430127041742287
# ERDE_5:0.13801543687522663
# ERDE_50:0.12194050513140492
# Median latency TPs:77.0
# Median penalty TPs:0.288014675005309
# Speed:0.711985324994691
# latency-weighted F1:0.09562053366534871
# ===================================================
# RANK-BASED EVALUATION:
# Analizing ranking at round 1
# Rank size:815
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.03850693239584506
# ===================================================
# Analizing ranking at round 50
# Rank size:815
# P@10:0.1
# NDCG@10:0.06343775459021642
# NDCG@100:0.1594103066292053
# ===================================================
# Analizing ranking at round 100
# Rank size:815
# P@10:0.2
# NDCG@10:0.12782810266318784
# NDCG@100:0.10444841814797806
# ===================================================
# Analizing ranking at round 500
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# Analizing ranking at round 1000
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# Analizing ranking at round 2000
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# []
# 0 entries in the run
#
#
# MODEL NUMBER: 4
#
# 815 lines read in qrels file!
#
#
# Connecting to...http://erisk.irlab.org/challenge-t1e/results/1f4c93c4e114d6e72706c31901101db7vv/3
# Response...200 OK
# 815 entries in the run
# ===================================================
# DECISION-BASED EVALUATION:
# Precision:0.09171974522292993
# Recall:0.9863013698630136
# F1:0.1678321678321678
# ERDE_5:0.0901255957514972
# ERDE_50:0.07958748917912085
# Median latency TPs:1.0
# Median penalty TPs:0.0
# Speed:1.0
# latency-weighted F1:0.1678321678321678
# ===================================================
# RANK-BASED EVALUATION:
# Analizing ranking at round 1
# Rank size:815
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.08245113463951013
# ===================================================
# Analizing ranking at round 50
# Rank size:815
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.09542513911131552
# ===================================================
# Analizing ranking at round 100
# Rank size:815
# P@10:0.3
# NDCG@10:0.19435097590153655
# NDCG@100:0.20476371314647143
# ===================================================
# Analizing ranking at round 500
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# Analizing ranking at round 1000
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# Analizing ranking at round 2000
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# []
# 0 entries in the run
#
#
# MODEL NUMBER: 5
#
# 815 lines read in qrels file!
#
#
# Connecting to...http://erisk.irlab.org/challenge-t1e/results/1f4c93c4e114d6e72706c31901101db7vv/4
# Response...200 OK
# 815 entries in the run
# ===================================================
# DECISION-BASED EVALUATION:
# Precision:0.10264900662251655
# Recall:0.4246575342465753
# F1:0.16533333333333333
# ERDE_5:0.10047023157734249
# ERDE_50:0.0813255367890927
# Median latency TPs:5.0
# Median penalty TPs:0.015598734651173896
# Speed:0.9844012653488261
# latency-weighted F1:0.16275434253767257
# ===================================================
# RANK-BASED EVALUATION:
# Analizing ranking at round 1
# Rank size:815
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0799759166425321
# ===================================================
# Analizing ranking at round 50
# Rank size:815
# P@10:0.2
# NDCG@10:0.3103875643828448
# NDCG@100:0.15625049256998796
# ===================================================
# Analizing ranking at round 100
# Rank size:815
# P@10:0.2
# NDCG@10:0.16294758424241468
# NDCG@100:0.13884881960356402
# ===================================================
# Analizing ranking at round 500
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# Analizing ranking at round 1000
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# Analizing ranking at round 2000
# Rank size:0
# P@10:0.0
# NDCG@10:0.0
# NDCG@100:0.0
# ===================================================
# []
# 0 entries in the run

# %%
r = requests.get("http://erisk.irlab.org/challenge-t1e/data/")

# %%
r.status_code
# Out:
# 404
