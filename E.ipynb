# %% [markdown]
# E MODEL
# ========
#
# This model is really similar to the C model, but instead of using the A model as pre-learning phase, uses the character embeddings of the D model.

# %% [markdown]
# Initialization of the Environment
# ==========================

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import collections
import tensorflow as tf
import os

np.random.seed(1)
tf.set_random_seed(2)

# %% [markdown]
# Load Data
# ========

# %%
import xml.etree.ElementTree as ET
import csv
import pandas as pd

# %%
SST_HOME='drive/My Drive/Colab Notebooks/Erisk2019/'
path_train=SST_HOME+'datas/training data - t1/2018 train/train.csv'
path_test=SST_HOME+'datas/training data - t1/2018 test/test.csv'

# %%
def listdir_fulllpath(d):
  return [os.path.join(d, f) for f in os.listdir(d)]

# %%
def parse_subject(path_xml):
  """
  This function will take the xmls return a pandas df.
  """
  tree = ET.parse(path_xml)
  root = tree.getroot()
  
  subject_id = root.find('ID').text
  writings = []
  
  # Read the xml
  for writing in root.findall('WRITING'):
    writing_data = {}
    writing_data['ID'] = subject_id
    writing_data['TITLE'] = writing.find('TITLE').text
    writing_data['DATE'] = writing.find('DATE').text
    writing_data['INFO'] = writing.find('INFO').text 
    writing_data['TEXT'] = writing.find('TEXT').text
    
    writings.append(writing_data)
    
  df = pd.DataFrame(writings)
  # If the record has no id or date return none
  try:
    df = df.set_index(['ID', 'DATE'])
  except:
    return None
  
  return df


def parse_folder(path_folder):
  """
  This function will parse a whole folder worth of records.
  
  Returns the records as a csv.
  """
  # Look for all the files in the directory
  files = []
  for f in os.listdir(path_folder):
      file_path = os.path.join(path_folder, f)
      if os.path.isfile(file_path):
        files.append(file_path)
  
  # Parse the xmls to pandas dataframes
  frames = [parse_subject(f) for f in files]
  
  # Merge the frames
  return pd.concat(frames)
  
def records_to_csv(path_records, path_csv, load=False):
  """
  This function will parse all the records into a csv
  """
  if load:
    if os.path.exists(path_csv):
      return pd.read_csv(path_csv).set_index(['ID', 'DATE'])
    else:
      print("File not found, can't load")
    
  
  frames = []
  test = False
  for f in listdir_fulllpath(path_records):
    
    # check if it is a test folder.
    if 'test' in f:
      test = True
      
    if os.path.isdir(f):
      for j in listdir_fulllpath(f):
        if os.path.isdir(j):
          frames.append(parse_folder(j))
          
  df = pd.concat(frames).sort_index()
  
  with open(path_records + 'risk_golden_truth.txt' if not test else path_records + 'risk-golden-truth-test.txt') as gt:
    df["LABEL"] = np.nan
    for line in gt:
      
      # The file ends with a newline, dont really know why
      if line == '\n':
        break
      
      rec_id, value = line.split()

      df.loc[rec_id, 'LABEL'] = value
      
  df.to_csv(path_csv)
  return df

# %%
print('started')
train_df = records_to_csv(SST_HOME+'datas/training data - t1/2018 train/', path_train, load=True)
print('completed train')
test_df = records_to_csv(SST_HOME+'datas/training data - t1/2018 test/', path_test, load=True)
print('completed test')
# Out:
# started
# completed train
# completed test

# %%
print(len(test_df), len(train_df))
# Out:
# 168507 84834

# %%
train_df.columns
# Out:
# Index(['INFO', 'TEXT', 'TITLE', 'LABEL'], dtype='object')

# %%
train_x_df = train_df[["TEXT", "TITLE"]]
train_y_df = train_df["LABEL"]

test_x_df = test_df[["TEXT", "TITLE"]]
test_y_df = test_df["LABEL"]

# %% [markdown]
# D Model Text
# ===========

# %%
train_x = [text + title for text, title in train_df[["TEXT", "TITLE"]].values]
train_y = train_df["LABEL"].values

test_x = [text + title for text, title in test_df[["TEXT", "TITLE"]].values]
test_y = test_df["LABEL"].values

# %%
train_balance = collections.Counter(train_y)
test_balance = collections.Counter(test_y)

print(train_balance)
print(test_balance)
# Out:
# Counter({0: 77382, 1: 7452})
# Counter({0: 151085, 1: 17422})

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from sklearn.feature_extraction.text import TfidfVectorizer

import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

stop_words=stopwords.words('english')
# Define maximum vocabulary length
MAX_WORDS = 5000
# Out:
# Using TensorFlow backend.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# We are using this function to clean the test set
def tokenize_clean_text(text, tfidf=True, tokenizer=None, max_length=None, max_words=MAX_WORDS):
  """
  This function is in charge of tokenizing the text it is given. It also cleans
  the text from stop-words, punctuation, and gives a special token to numbers.
  
  :param text: The texts to tokenize in a bidimensional python array.
  
  :returns: The tokenized and cleaned text in a bidimensional python array.
            The tokenizer used to preprocess the text.
            The maximum length used for padding.
  """   
  # set [removed] as a special token
  text_removed = [t.replace("[removed]", "R3MOV3D") for t in text]
  
  # We remove the numbers
  cropped_numbers_text = [" ".join([word if not word.isdigit() else ""
                                for word in sentence.split()])
                               for sentence in text_removed]
  
  # Delete stopwords as well as every word less than 3 chars.
  cropped_numbers_stopw_text = [" ".join([word if not (word in stop_words or len(word) <= 3) else ""
                                      for word in sentence.split()])
                                     for sentence in cropped_numbers_text]
  
  if tfidf:
    vec = TfidfVectorizer(max_features=max_words)
    tfidf_mat = vec.fit_transform(cropped_numbers_stopw_text).toarray()
    tfid_words = vec.get_feature_names()

    cropped_numbers_stopw_tfidf_text = [" ".join([word if word in tfid_words else ""
                                            for word in sentence.split()])
                                            for sentence in cropped_numbers_stopw_text]
  
  if tokenizer is None:
    tokenizer = Tokenizer(num_words=max_words) # They use 5k words too
    tokenizer.fit_on_texts(cropped_numbers_stopw_tfidf_text if tfidf else cropped_numbers_stopw_text)
  # We tokenize the sentences
  tokenized_text = tokenizer.texts_to_sequences(cropped_numbers_stopw_tfidf_text if tfidf else cropped_numbers_stopw_text)
  
  if max_length == None:
    max_length = 0
    for sentence in tokenized_text:
      max_length = max_length if len(sentence) < max_length else len(sentence)
  
  # Now we return the padded the sequences.
  return pad_sequences(tokenized_text, max_length), tokenizer, max_length, cropped_numbers_stopw_tfidf_text if tfidf else cropped_numbers_stopw_text

# %%
train_x_token, tokenizer, max_length, train_x_clean = tokenize_clean_text(train_x) 
test_x_token, _, _, test_x_clean = tokenize_clean_text(test_x, tokenizer=tokenizer)

# %%
token_index = np.unique(train_x_token)

# %%
max_words = len(token_index)

# %%
import matplotlib.pyplot as plt

lengths  = np.array([len(sentence.split()) for sentence in test_x_clean if len(sentence.split()) < 400])
plt.hist(lengths, bins=100, cumulative = True)
plt.title("TFIDF text")
plt.show()

# %%
train_x_char = [[c for c in instance] for instance in train_x_clean]
test_x_char = [[c for c in instance] for instance in test_x_clean]

# %%
lengths = np.array([len(sentence) for sentence in test_x_char if len(sentence) < 1500])
plt.hist(lengths, bins=100, cumulative=True)
plt.title("CHAR text")
plt.xlabel("Length")
plt.ylabel("Ocurrences")
plt.show()

# %%
# the length will be set to 400
max_length = 400
train_x_char_padded = [["."]*(max_length - len(instance)) + instance if len(instance) < max_length else instance for instance in train_x_char]
test_x_char_padded = [["."]*(max_length - len(instance)) + instance if len(instance) < max_length else instance for instance in test_x_char]

train_x_char_crop = [instance[-400:] for instance in train_x_char_padded]
test_x_char_crop = [instance[-400:] for instance in test_x_char_padded]

# %%
def tokenize_chars(text, tokenizer=None, max_length=max_length):
  if tokenizer is None:
    tokenizer = Tokenizer() # They use 5k words too
    tokenizer.fit_on_texts(text)
  # We tokenize the sentences
  tokenized_text = tokenizer.texts_to_sequences(text)
  
  for i, t in enumerate(tokenized_text):
    if len(t) < max_length:
      tokenized_text[i] = [1] * (max_length - len(t)) + tokenized_text[i]
      
  return tokenized_text, tokenizer

# %%
train_x_char_crop_token, char_tokenizer = tokenize_chars(train_x_char_crop)
test_x_char_crop_token, _ = tokenize_chars(test_x_char_crop, char_tokenizer)

# %%
train_x_df["TOK_CHAR"] = train_x_char_crop_token
test_x_df["TOK_CHAR"] = test_x_char_crop_token
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# Neural Network
# ==============
# The neural network begins here. The first part of it is a pre-trained model A. Which was used in this task too. They will be used as a "embedding layer" for the writtings of each subject.
#
# The rest of the network will have the different subject writting embeddings as input of a RNN-type layer. Specifically to take into account th etemporal information. (It may probably change to CNN but we can have a look at that in the future work)

# %%
import keras
from keras import backend as K
from keras.models import Model
from keras.layers import Dense, Activation, Embedding, Dropout, Input
from keras.layers import Lambda, Flatten, RepeatVector, Permute, Multiply
from keras.layers import LSTM, GRU, Bidirectional, BatchNormalization
from keras.layers import Conv1D, MaxPooling1D, Concatenate

from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.losses import binary_crossentropy
from keras.optimizers import RMSprop, Adam

from keras.models import load_model
from keras.models import Sequential

# %%
D_MODELS_PATH = SST_HOME + "DL/models/D/best_models/"
MODEL_PATH = D_MODELS_PATH + "Copia de load_emb_False_num_classes_1_emb_size_50_trainable_emb_True_cnn_size_128_cnn_filter_10_rnn_size_None_cell_type_LSTM_bidirectional_False_attention_False_dropout_0.5_dnn_size_64_batch_size_1024"

# %%
from keras.models import load_model

e_model = load_model(MODEL_PATH)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
e_model.layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x7f306dda7048>,
#  <keras.layers.embeddings.Embedding at 0x7f306dda74e0>,
#  <keras.layers.convolutional.Conv1D at 0x7f306dda7128>,
#  <keras.layers.core.Flatten at 0x7f306dda7b70>,
#  <keras.layers.core.Dense at 0x7f306dda7be0>,
#  <keras.layers.core.Dropout at 0x7f306ff4cdd8>,
#  <keras.layers.core.Dense at 0x7f306ff4cbe0>]

# %%
e_model.layers.pop()
e_model.layers.pop()
# We pop two layers, being them the output and the last Dropout layers
d_model = Sequential()

for layer in e_model.layers:
  d_model.add(layer)

# %%
instances = np.array(train_x_df["TOK_CHAR"].tolist())
instances_test = np.array(test_x_df["TOK_CHAR"].tolist())

# %%
embedded_text = d_model.predict(instances)
embedded_text_test = d_model.predict(instances_test)

# %%
train_x_df["CHAR_EMBED"] = embedded_text.tolist()
test_x_df["CHAR_EMBED"] = embedded_text_test.tolist()

# %%
# Set the size of the embeddings depending on the embeddings generated
input_size = len(train_x_df.iloc[0]["CHAR_EMBED"])

# %%
train_x_subjects = []
train_y_subjects = []
for subject in train_x_df.index.get_level_values(0).unique():
  train_x_subjects.append(train_x_df.loc[subject]["CHAR_EMBED"].tolist())
  train_y_subjects.append(train_y_df.loc[subject].values[0])
  
test_x_subjects = []
test_y_subjects = []
for subject in test_x_df.index.get_level_values(0).unique():
  test_x_subjects.append(test_x_df.loc[subject]["CHAR_EMBED"].tolist())
  test_y_subjects.append(test_y_df.loc[subject].values[0])

# %% [markdown]
# # **TensorBoard**
# TensorBoard is a great tool for DL visualization. It shows the evolution of metrics during the training phase, as well as the weights, distributions, and even the graph of the neural net.
#
# We will be using tensorboardcolab in order to run a
# TensorBoard instance. This will initialize a ngrok machine and launch TensorBoard for us to see.
#
# TensorBoard will be accesible by the url

# %%
# We install tensorboard colab in case we don't have it already.
# !pip install tensorboardcolab
# Out:
# Requirement already satisfied: tensorboardcolab in /usr/local/lib/python3.6/dist-packages (0.0.22)

# %%
import tensorboardcolab as tb

tbc=tb.TensorBoardColab()
# Out:
# Wait for 8 seconds...
# TensorBoard link:
# https://71901a51.ngrok.io

# %% [markdown]
# Experiments Configuration
# =====================

# %%
tfidf = [False] # Not changing
concept_emb = [False]  # Not Changing 
load_emb = [False]  # Not Changing
num_classes = [None]  # Not changing
emb_size = [None]  # Not changing, addressed later
trainable_emb = [False]  # Not changing
cnn_size = [[None]]  # Not changing
cnn_filter = [[3]]  # Not changing
rnn_size = [[64]]
cell_type = [GRU, LSTM]
bidirectional = [True, False]
attention = [False]
dropout = [0.5]
dnn_size = [[32]]
batch_size = [1]

indexes = ["load_emb", "emb_size", "trainable_emb", "cnn_size", "cnn_filter", "rnn_size", "cell_type", "bidirectional", "attention", "dropout", "dnn_size", "batch_size"]
param   = [load_emb, emb_size, trainable_emb, cnn_size, cnn_filter, rnn_size, cell_type, bidirectional, attention, dropout, dnn_size, batch_size]

# %%
import itertools

def combine_params(param, indexes):
  """
  This function is in charge of combining the parameters. This way we can perform a grid search automatically.
  
  Inputs: The array of different parameters, and the indexes for them.
  
  Outputs: The dictionary of different configurations made.
  """
  combinations = list(itertools.product(*param))
  param_combinations = [{k:v for k, v in zip(indexes, combination)}  for combination in combinations]
  for p in param_combinations:
    # The embeddings size must adapt to the embeddings loaded.
    if p["load_emb"]:
      p["emb_size"] = None
    else:
      p["embedding_matrix"] = None
  return param_combinations

# %%
network_parameters = combine_params(param, indexes)

# %%
network_parameters
# Out:
# [{'attention': False,
#   'batch_size': 1,
#   'bidirectional': True,
#   'cell_type': keras.layers.recurrent.GRU,
#   'cnn_filter': [3],
#   'cnn_size': [None],
#   'dnn_size': [32],
#   'dropout': 0.5,
#   'emb_size': None,
#   'embedding_matrix': None,
#   'load_emb': False,
#   'rnn_size': [64],
#   'trainable_emb': False},
#  {'attention': False,
#   'batch_size': 1,
#   'bidirectional': False,
#   'cell_type': keras.layers.recurrent.GRU,
#   'cnn_filter': [3],
#   'cnn_size': [None],
#   'dnn_size': [32],
#   'dropout': 0.5,
#   'emb_size': None,
#   'embedding_matrix': None,
#   'load_emb': False,
#   'rnn_size': [64],
#   'trainable_emb': False},
#  {'attention': False,
#   'batch_size': 1,
#   'bidirectional': True,
#   'cell_type': keras.layers.recurrent.LSTM,
#   'cnn_filter': [3],
#   'cnn_size': [None],
#   'dnn_size': [32],
#   'dropout': 0.5,
#   'emb_size': None,
#   'embedding_matrix': None,
#   'load_emb': False,
#   'rnn_size': [64],
#   'trainable_emb': False},
#  {'attention': False,
#   'batch_size': 1,
#   'bidirectional': False,
#   'cell_type': keras.layers.recurrent.LSTM,
#   'cnn_filter': [3],
#   'cnn_size': [None],
#   'dnn_size': [32],
#   'dropout': 0.5,
#   'emb_size': None,
#   'embedding_matrix': None,
#   'load_emb': False,
#   'rnn_size': [64],
#   'trainable_emb': False}]

# %%
# We change the number of classes automatically
for p in network_parameters:
  p["max_length"] = input_size
  p["max_words"] = max_words
  try:
    p["num_classes"] = train_y.shape[1]
  except IndexError:
    p["num_classes"] = 1

# %% [markdown]
# Neural Network
# =============

# %%
def add_embeddings(z, load, size, trainable, vocab_size, max_length, embedding_matrix): 
  """
  This method adds embeddings to the network.
  
  Returns the net with the embeddings added.
  """
  print(size)
  if size is None:
    return z
  
  if load:
    z = Embedding(vocab_size, size, input_length=max_length, weights=[embedding_matrix], trainable=trainable)(z)
  else:
    z = Embedding(vocab_size, size, input_length=max_length)(z)
    
  return z

def add_cnn(z, size, filter_sizes, flatten):
  """
  This method adds the CNN layers to the network.
  
  Returns the net with the CNN layers.
  """
  conv_blocks = []
  for filter_size in filter_sizes:
    if filter_size is None:
      return z
    conv = None
    for i, cnn_layer in enumerate(size):
      if cnn_layer is None:
        return z
      conv = Conv1D(cnn_layer, filter_size, padding='valid', activation='relu', strides=1)(z if conv is None else conv)
      # if (i + 1)  % 2 == 0:
      conv = MaxPooling1D(pool_size=filter_size)(conv)        
      
    if flatten:
      conv = Flatten()(conv)
    conv_blocks.append(conv)         
 
  z = Concatenate()(conv_blocks) if len(conv_blocks) > 1 else conv_blocks[0]
  
  return z

def add_rnn(z, size, bidirectional, cell_type, attention):
  """
  This method adds the RNN layers to the network. It also adds an attention layer if intended.
  
  Returns the net with the RNN & Attention added.
  """
  for i, rsz in enumerate(size):
    if rsz is None:
      return z
    if not bidirectional:
      if i < len(size) - 1:
        z = cell_type(rsz, return_sequences=True)(z)
      else:
        z = cell_type(rsz, return_sequences=attention)(z)
    else:
      if i < len(size) - 1:
        z = Bidirectional(cell_type(rsz, return_sequences=True))(z)
      else:
        z = Bidirectional(cell_type(rsz, return_sequences=attention))(z)

  if attention:
    z = add_attention(z)

  return z

def add_dnn(z, size, dropout, activation="relu"):
  """
  This method adds the DNN layers to the network.
  
  Returns the net with the DNN layers added.
  """
  for fsz in size:
    if fsz is None:
      return z

    z = Dense(fsz, activation=activation)(z)
    z = Dropout(dropout)(z)
    
  return z

def add_attention(activations):
  """
  This method adds an attention layer.
  
  Returns the model with the attention layer.
  """
  
  size =  K.int_shape(activations)[-1]
  attention = BatchNormalization()(activations)
  attention = Dense(1, activation='tanh')(attention)
  attention = Flatten()(attention)
  attention = Activation('softmax')(attention)
  attention = RepeatVector(size)(attention)
  attention = Permute([2, 1])(attention)
  
  z = Multiply()([activations, attention])
  z = Lambda(lambda xin: K.sum(xin, axis=-2), output_shape=(size,))(z)

  return z

# %%
def create_model(params):
  """
  This method creates a network model with the parameters given.
  
  Returns the uncompiled model.
  """
  # We changed a bit the model to get variable length inputs.
  inputs = Input(name='inputs',shape=(None, params["max_length"]))
  
  z = add_embeddings(inputs, params["load_emb"], params["emb_size"], params["trainable_emb"], params["max_words"] ,params["max_length"], params["embedding_matrix"])
  
  z = add_cnn(z, params["cnn_size"], params["cnn_filter"], [None] == params["rnn_size"])
  
  z = add_rnn(z, params["rnn_size"], params["bidirectional"], params["cell_type"], params["attention"])
  
  z = add_dnn(z, params["dnn_size"], params["dropout"])
  
  outputs = Dense(params["num_classes"], activation='sigmoid', name='output_layer')(z)
  
  net_model = Model(inputs=inputs,outputs=outputs)
  
  return net_model

# %%
def create_models(network_parameters, verbose=False):
  model_list = []
  for net_p in network_parameters:
    m = create_model(net_p)
    m.compile(loss='binary_crossentropy', optimizer='adam', metrics=['binary_accuracy'])
    model_list.append(m)
    
    if verbose:
      m.summary()
      
  return model_list

# %%
model_list = create_models(network_parameters, verbose=True)
# Out:
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, None, 64)          0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 128)               49536
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 33
# =================================================================
# Total params: 53,697
# Trainable params: 53,697
# Non-trainable params: 0
# _________________________________________________________________
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, None, 64)          0
# _________________________________________________________________
# gru_2 (GRU)                  (None, 64)                24768
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 33
# =================================================================
# Total params: 26,881
# Trainable params: 26,881
# Non-trainable params: 0
# _________________________________________________________________
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, None, 64)          0
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 128)               66048
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 33
# =================================================================
# Total params: 70,209
# Trainable params: 70,209
# Non-trainable params: 0
# _________________________________________________________________
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, None, 64)          0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 32)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 33
# =================================================================
# Total params: 35,137
# Trainable params: 35,137
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # TB Colab Callback
# We rewrite the tensorboardcolab callbacks to create different sessions depending on the variables our trainings have. This helps to differentiate the models in tensorboard.

# %%
import os
from keras.callbacks import TensorBoard
import tensorflow as tf

class TensorBoardColabCallback(TensorBoard):
    def __init__(self, tbc=None, write_graph=True, name=None, **kwargs):
        # Make the original `TensorBoard` log to a subdirectory 'training'

        if tbc is None:
            return

        log_dir = tbc.get_graph_path()

        training_log_dir = os.path.join(log_dir, 'training_{}'.format(name))
        super(TensorBoardColabCallback, self).__init__(training_log_dir, **kwargs)

        # Log the validation metrics to a separate subdirectory
        self.val_log_dir = os.path.join(log_dir, 'validation_{}'.format(name))

    def set_model(self, model):
        # Setup writer for validation metrics
        self.val_writer = tf.summary.FileWriter(self.val_log_dir)
        super(TensorBoardColabCallback, self).set_model(model)

    def on_epoch_end(self, epoch, logs=None):
        # Pop the validation logs and handle them separately with
        # `self.val_writer`. Also rename the keys so that they can
        # be plotted on the same figure with the training metrics
        logs = logs or {}
        val_logs = {k.replace('val_', ''): v for k, v in logs.items() if k.startswith('val_')}

        for name, value in val_logs.items():
            # print('val_logs:',epoch, name, value)
            summary = tf.Summary()
            summary_value = summary.value.add()
            summary_value.simple_value = value.item()
            summary_value.tag = name
            self.val_writer.add_summary(summary, epoch)
        self.val_writer.flush()

        # Pass the remaining logs to `TensorBoard.on_epoch_end`
        logs = {k: v for k, v in logs.items() if not k.startswith('val_')}
        super(TensorBoardColabCallback, self).on_epoch_end(epoch, logs)
        
    def on_train_end(self, logs=None):
        super(TensorBoardColabCallback, self).on_train_end(logs)
        self.val_writer.close()

tb.TensorBoardColabCallback = TensorBoardColabCallback

# %%
def define_callbacks(name):
  # Define the callbacks
  tbc_callback = tb.TensorBoardColabCallback(tbc, name=name)  # , histogram_freq=1)
   
  callbacks = [
      ReduceLROnPlateau(),
      EarlyStopping(patience=4),
      tbc_callback
  ]
  return callbacks

# %%
# Create an array of names
network_names = []
for p in network_parameters:
  name = "load_emb_{}_num_classes_{}_emb_size_{}_trainable_emb_{}_cnn_size_{}_cnn_filter_{}_pool_rnn_size_{}_cell_type_{}_bidirectional_{}_attention_{}_dropout_{}_dnn_size_{}_batch_size_{}".format(
      p["load_emb"], p["num_classes"], p["emb_size"], p["trainable_emb"], p["cnn_size"], p["cnn_filter"], p["rnn_size"], 
      str(p["cell_type"]).split(".")[-1].replace("'", "").replace(">", ""), p["bidirectional"],
      p["attention"], p["dropout"], p["dnn_size"], p["batch_size"])
  name = name.replace(" ", "").replace("[", "").replace("]", "").replace(",", "-")
  network_names.append(name)

# %%
for i, net_model in enumerate(model_list):
  # Set a name for the model based on the tweaked parameters
  p = network_parameters[i]
  name = network_names[i]
  model_path = SST_HOME+"DL/models/E/" + name

  # If the model exists, don't compute it again.
  if os.path.isfile(model_path):
    continue
    
  print("\n\n********************************************\n")    
  print(name)
  callbacks = define_callbacks(name)
  # Fit the model and extract its data
  for epoch in range(20):
    print("Epoch {}\n".format(epoch))
    for subject, label in zip(train_x_subjects, train_y_subjects):
      history = net_model.fit(np.array([subject]), np.array([label]), callbacks=callbacks, class_weight={0: 0.11, 1: 0.89})
    
  # And save the model
  net_model.save(model_path)
  
# To free memory from the gpu
from keras import backend as K
K.clear_session()
# Out:
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_LSTM_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_1
# Epoch 0
#
# Epoch 1/1
# 1/1 [==============================] - 2s 2s/step - loss: 0.0598 - binary_accuracy: 1.0000
# /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1109: RuntimeWarning: Reduce LR on plateau conditioned on metric `val_loss` which is not available. Available metrics are: loss,binary_accuracy,lr
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:569: RuntimeWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,binary_accuracy,lr
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# Epoch 1/1
# 1/1 [==============================] - 1s 655ms/step - loss: 0.0618 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 50ms/step - loss: 1.4742 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0396 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 154ms/step - loss: 0.0436 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 423ms/step - loss: 0.0737 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0700 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0753 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 159ms/step - loss: 0.0683 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0662 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0774 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0694 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0620 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 840ms/step - loss: 0.0744 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0747 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 166ms/step - loss: 0.0576 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 570ms/step - loss: 0.0723 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 703ms/step - loss: 0.0436 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0412 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0368 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0600 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 799ms/step - loss: 0.0613 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 659ms/step - loss: 0.0493 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0855 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 677ms/step - loss: 0.0623 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0531 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 380ms/step - loss: 0.0346 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 255ms/step - loss: 0.0302 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 158ms/step - loss: 0.0497 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 814ms/step - loss: 0.9506 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0442 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0426 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 659ms/step - loss: 0.0461 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0479 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 831ms/step - loss: 0.0145 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0308 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0560 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 33ms/step - loss: 0.6182 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 858ms/step - loss: 0.0292 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 24ms/step - loss: 1.2647 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0255 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 984ms/step - loss: 0.0410 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0609 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 781ms/step - loss: 0.0357 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0255 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0561 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 743ms/step - loss: 0.0292 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0396 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0515 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 792ms/step - loss: 0.0286 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0763 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0336 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0271 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0602 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0686 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 755ms/step - loss: 0.0310 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 313ms/step - loss: 0.0501 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 519ms/step - loss: 0.0480 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0436 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 399ms/step - loss: 0.0476 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0197 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0405 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 762ms/step - loss: 0.0412 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0187 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 677ms/step - loss: 0.0325 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 390ms/step - loss: 0.0399 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0179 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 192ms/step - loss: 0.0431 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 297ms/step - loss: 0.0192 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0265 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0326 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 149ms/step - loss: 0.0542 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 923ms/step - loss: 0.0083 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0063 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0356 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 998ms/step - loss: 0.0065 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 239ms/step - loss: 0.0444 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0068 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 219ms/step - loss: 0.0153 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0068 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 708ms/step - loss: 0.0101 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0264 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 632ms/step - loss: 0.0297 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 148ms/step - loss: 0.0163 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 45ms/step - loss: 1.4340 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0257 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0218 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 170ms/step - loss: 1.3865 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0144 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 794ms/step - loss: 0.0213 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 926ms/step - loss: 0.0473 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 935ms/step - loss: 0.0308 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 259ms/step - loss: 0.0286 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0224 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0337 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 809ms/step - loss: 0.0137 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 381ms/step - loss: 2.3825 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0143 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0409 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 432ms/step - loss: 0.0248 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 281ms/step - loss: 0.0532 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 735ms/step - loss: 0.0411 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 671ms/step - loss: 0.0551 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0427 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 162ms/step - loss: 0.0623 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 281ms/step - loss: 0.0497 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 737ms/step - loss: 0.0480 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 727ms/step - loss: 0.0547 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 679ms/step - loss: 0.0506 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 134ms/step - loss: 0.0428 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0459 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 235ms/step - loss: 0.0638 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0370 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 386ms/step - loss: 0.0725 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0474 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 530ms/step - loss: 0.0504 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 406ms/step - loss: 0.0735 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 358ms/step - loss: 0.0591 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0436 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0506 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0560 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 259ms/step - loss: 0.0373 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0613 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0611 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 147ms/step - loss: 0.0566 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0497 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 216ms/step - loss: 0.0501 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0527 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0504 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 716ms/step - loss: 0.0311 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0444 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 189ms/step - loss: 0.0398 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 666ms/step - loss: 0.0484 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0544 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0547 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 735ms/step - loss: 0.0260 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 16ms/step - loss: 0.9677 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 428ms/step - loss: 0.0503 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 151ms/step - loss: 0.0359 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 158ms/step - loss: 0.0526 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 273ms/step - loss: 0.9952 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 297ms/step - loss: 0.7216 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 358ms/step - loss: 1.0627 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 48ms/step - loss: 1.1919 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 70ms/step - loss: 0.7198 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6371 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 88ms/step - loss: 0.7688 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6827 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 715ms/step - loss: 0.6130 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6626 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 606ms/step - loss: 0.7204 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 810ms/step - loss: 0.6586 - binary_accuracy: 0.0000e+00
# Epoch 1
#
# Epoch 1/1
# 1/1 [==============================] - 1s 775ms/step - loss: 0.0729 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 676ms/step - loss: 0.0612 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 50ms/step - loss: 0.7280 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 138ms/step - loss: 0.0659 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 164ms/step - loss: 0.0768 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 371ms/step - loss: 0.0804 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0794 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0770 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 163ms/step - loss: 0.0797 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0770 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0764 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0805 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0832 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 876ms/step - loss: 0.0802 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0759 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 166ms/step - loss: 0.0757 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 514ms/step - loss: 0.0777 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 723ms/step - loss: 0.0736 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0730 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0821 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0815 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 727ms/step - loss: 0.0778 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 660ms/step - loss: 0.0784 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0779 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 659ms/step - loss: 0.0667 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0778 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 286ms/step - loss: 0.0654 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 240ms/step - loss: 0.0796 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 168ms/step - loss: 0.0654 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 850ms/step - loss: 0.5934 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0637 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0625 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 717ms/step - loss: 0.0800 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0595 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 891ms/step - loss: 0.0770 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 128ms/step - loss: 0.0580 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0796 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 33ms/step - loss: 0.8100 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 933ms/step - loss: 0.0505 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 27ms/step - loss: 0.8262 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0575 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 938ms/step - loss: 0.0764 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0624 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 737ms/step - loss: 0.0805 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0713 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0644 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 823ms/step - loss: 0.0740 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0772 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0793 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 794ms/step - loss: 0.0761 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0750 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0778 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0778 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0714 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0648 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 759ms/step - loss: 0.0748 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 314ms/step - loss: 0.0732 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 522ms/step - loss: 0.0771 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0635 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 405ms/step - loss: 0.0778 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0622 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0608 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 778ms/step - loss: 0.0711 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0657 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 703ms/step - loss: 0.0685 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 403ms/step - loss: 0.0698 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0608 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 202ms/step - loss: 0.0651 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0632 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0620 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 382ms/step - loss: 0.0609 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 149ms/step - loss: 0.0771 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 953ms/step - loss: 0.0543 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0428 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0789 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0621 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 242ms/step - loss: 0.0504 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0764 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 222ms/step - loss: 0.0383 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0616 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 796ms/step - loss: 0.0355 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0355 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 657ms/step - loss: 0.0775 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 150ms/step - loss: 0.0323 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9581 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0753 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0447 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 175ms/step - loss: 0.8964 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0449 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 787ms/step - loss: 0.0590 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 935ms/step - loss: 0.0683 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 940ms/step - loss: 0.0685 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 264ms/step - loss: 0.0441 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0567 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0529 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 851ms/step - loss: 0.0468 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 389ms/step - loss: 0.7856 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0615 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0673 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 401ms/step - loss: 0.0605 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 255ms/step - loss: 0.0701 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 732ms/step - loss: 0.0660 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 656ms/step - loss: 0.0644 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0694 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 174ms/step - loss: 0.0664 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 278ms/step - loss: 0.0542 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 700ms/step - loss: 0.0562 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 724ms/step - loss: 0.0635 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 669ms/step - loss: 0.0776 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 132ms/step - loss: 0.0759 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0764 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 231ms/step - loss: 0.0776 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 264ms/step - loss: 0.0565 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 378ms/step - loss: 0.0775 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0724 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 528ms/step - loss: 0.0705 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 405ms/step - loss: 0.0553 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 359ms/step - loss: 0.0722 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0576 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0529 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0761 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 380ms/step - loss: 0.0645 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0752 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0537 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 155ms/step - loss: 0.0722 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0653 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 217ms/step - loss: 0.0485 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0727 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 296ms/step - loss: 0.0597 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 711ms/step - loss: 0.0494 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0379 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 188ms/step - loss: 0.0773 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 748ms/step - loss: 0.0568 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0601 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0746 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 741ms/step - loss: 0.0594 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 17ms/step - loss: 0.9979 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 438ms/step - loss: 0.0574 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 151ms/step - loss: 0.0480 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 155ms/step - loss: 0.0744 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 273ms/step - loss: 0.6088 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 299ms/step - loss: 0.9072 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 356ms/step - loss: 0.6734 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 48ms/step - loss: 0.7642 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 70ms/step - loss: 0.6205 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 24ms/step - loss: 0.7432 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 90ms/step - loss: 0.6227 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 54ms/step - loss: 0.7388 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 820ms/step - loss: 0.6379 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6134 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 610ms/step - loss: 0.6000 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 803ms/step - loss: 0.6076 - binary_accuracy: 1.0000
# Epoch 2
#
# Epoch 1/1
# 1/1 [==============================] - 1s 871ms/step - loss: 0.0788 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 675ms/step - loss: 0.0791 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 44ms/step - loss: 0.6016 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0794 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 159ms/step - loss: 0.0788 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 486ms/step - loss: 0.0802 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0800 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0785 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 159ms/step - loss: 0.0792 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0801 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0781 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0786 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0802 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 864ms/step - loss: 0.0791 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0788 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 165ms/step - loss: 0.0782 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 521ms/step - loss: 0.0770 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 716ms/step - loss: 0.0801 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0793 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0781 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0759 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 688ms/step - loss: 0.0800 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 639ms/step - loss: 0.0760 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0785 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 678ms/step - loss: 0.0735 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0737 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 578ms/step - loss: 0.0726 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 247ms/step - loss: 0.0792 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 226ms/step - loss: 0.0792 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 808ms/step - loss: 0.6507 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0740 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0712 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 670ms/step - loss: 0.0771 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 143ms/step - loss: 0.0707 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 819ms/step - loss: 0.0729 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 127ms/step - loss: 0.0786 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0715 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 34ms/step - loss: 0.5982 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 913ms/step - loss: 0.0725 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6188 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0724 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 935ms/step - loss: 0.0764 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0787 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 749ms/step - loss: 0.0715 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0712 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0787 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 739ms/step - loss: 0.0694 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0706 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0732 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 805ms/step - loss: 0.0787 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0679 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0787 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0672 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0667 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0786 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 777ms/step - loss: 0.0774 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 321ms/step - loss: 0.0772 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 529ms/step - loss: 0.0660 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0637 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 406ms/step - loss: 0.0687 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0637 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0786 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 841ms/step - loss: 0.0766 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0763 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 681ms/step - loss: 0.0595 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 394ms/step - loss: 0.0602 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0606 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 312ms/step - loss: 0.0754 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0785 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 274ms/step - loss: 0.0589 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 262ms/step - loss: 0.0583 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 149ms/step - loss: 0.0748 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0743 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0551 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0526 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0551 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 256ms/step - loss: 0.0784 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0523 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 242ms/step - loss: 0.0726 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0777 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 701ms/step - loss: 0.0452 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0450 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 745ms/step - loss: 0.0446 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 149ms/step - loss: 0.0704 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 48ms/step - loss: 0.8938 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0479 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0705 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 166ms/step - loss: 0.6554 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0783 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 786ms/step - loss: 0.0567 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 984ms/step - loss: 0.0627 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 920ms/step - loss: 0.0783 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 301ms/step - loss: 0.0371 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0429 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0593 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 820ms/step - loss: 0.0498 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 381ms/step - loss: 1.1396 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0422 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0603 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 397ms/step - loss: 0.0784 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 269ms/step - loss: 0.0772 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 849ms/step - loss: 0.0582 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 670ms/step - loss: 0.0767 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0562 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0773 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0777 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 828ms/step - loss: 0.0774 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 723ms/step - loss: 0.0780 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 631ms/step - loss: 0.0784 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0591 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0624 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 228ms/step - loss: 0.0636 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 261ms/step - loss: 0.0783 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0606 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0628 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 506ms/step - loss: 0.0614 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 482ms/step - loss: 0.0783 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 346ms/step - loss: 0.0654 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0579 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0582 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0638 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 256ms/step - loss: 0.0572 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0581 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0572 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 147ms/step - loss: 0.0601 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0755 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 216ms/step - loss: 0.0539 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0621 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0737 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 725ms/step - loss: 0.0722 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0470 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 187ms/step - loss: 0.0463 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 668ms/step - loss: 0.0571 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0445 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0688 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 741ms/step - loss: 0.0672 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6905 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 439ms/step - loss: 0.0770 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 167ms/step - loss: 0.0455 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 156ms/step - loss: 0.0410 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 354ms/step - loss: 0.7130 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 298ms/step - loss: 0.6750 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 356ms/step - loss: 0.8483 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 46ms/step - loss: 0.8240 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 72ms/step - loss: 0.5965 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6038 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 162ms/step - loss: 0.7819 - binary_accuracy: 0.0000e+00
# ...
# Epoch 1/1
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0827 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0827 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 239ms/step - loss: 0.0828 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0829 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 832ms/step - loss: 0.0829 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0847 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0831 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 727ms/step - loss: 0.0830 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0830 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0831 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 579ms/step - loss: 0.0831 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 906ms/step - loss: 0.0896 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0831 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 360ms/step - loss: 0.0831 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 697ms/step - loss: 0.0831 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0831 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0831 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0831 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 492ms/step - loss: 0.0868 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 468ms/step - loss: 0.0831 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0831 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 442ms/step - loss: 0.0831 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0829 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 362ms/step - loss: 0.0830 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 160ms/step - loss: 0.0830 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0830 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 548ms/step - loss: 0.5053 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0830 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0831 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 445ms/step - loss: 0.0830 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0830 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 543ms/step - loss: 0.0830 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 154ms/step - loss: 0.0830 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0866 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 27ms/step - loss: 0.5394 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 552ms/step - loss: 0.0874 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5657 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 832ms/step - loss: 0.0830 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0830 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0830 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 497ms/step - loss: 0.0830 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0830 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 830ms/step - loss: 0.0830 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 508ms/step - loss: 0.0830 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0830 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0834 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 534ms/step - loss: 0.0830 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0830 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0830 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0833 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0830 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 845ms/step - loss: 0.0829 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 509ms/step - loss: 0.0906 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 206ms/step - loss: 0.0829 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 359ms/step - loss: 0.0829 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 844ms/step - loss: 0.0837 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0833 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0829 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0828 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 530ms/step - loss: 0.0920 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0828 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 463ms/step - loss: 0.0828 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 293ms/step - loss: 0.0829 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0827 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 135ms/step - loss: 0.0830 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 195ms/step - loss: 0.0827 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 181ms/step - loss: 0.0827 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 173ms/step - loss: 0.0827 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 144ms/step - loss: 0.0832 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 619ms/step - loss: 0.0826 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0826 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0826 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 774ms/step - loss: 0.0826 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 155ms/step - loss: 0.0826 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0825 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 146ms/step - loss: 0.0825 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0825 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 750ms/step - loss: 0.0825 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0839 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 434ms/step - loss: 0.0836 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0824 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0135 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0824 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0823 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 114ms/step - loss: 0.5703 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0823 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 543ms/step - loss: 0.1145 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0823 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 617ms/step - loss: 0.0827 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 173ms/step - loss: 0.0823 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 996ms/step - loss: 0.0823 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0823 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 576ms/step - loss: 0.0823 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 301ms/step - loss: 0.5708 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 158ms/step - loss: 0.0823 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0921 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 286ms/step - loss: 0.0823 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 180ms/step - loss: 0.0928 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 522ms/step - loss: 0.0825 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 475ms/step - loss: 0.0822 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0822 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0992 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 184ms/step - loss: 0.0822 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 527ms/step - loss: 0.0822 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 483ms/step - loss: 0.0822 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 406ms/step - loss: 0.0822 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0822 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0818 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 148ms/step - loss: 0.0821 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 178ms/step - loss: 0.0821 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 255ms/step - loss: 0.0821 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0819 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 349ms/step - loss: 0.0820 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 263ms/step - loss: 0.0820 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 238ms/step - loss: 0.0820 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0820 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0820 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0838 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 172ms/step - loss: 0.0820 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0819 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0819 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0814 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0819 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 147ms/step - loss: 0.0819 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0891 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 180ms/step - loss: 0.0816 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 486ms/step - loss: 0.0818 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0818 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0818 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 437ms/step - loss: 0.0817 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0817 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.0817 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 489ms/step - loss: 0.0817 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5752 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0816 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0816 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0816 - binary_accuracy: 0.0000e+00
# Epoch 1/1
# 1/1 [==============================] - 0s 180ms/step - loss: 0.5754 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 195ms/step - loss: 0.5753 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 239ms/step - loss: 0.5752 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5749 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 48ms/step - loss: 0.5510 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 18ms/step - loss: 0.5741 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 60ms/step - loss: 0.5736 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 37ms/step - loss: 0.5731 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 459ms/step - loss: 0.0939 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5719 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 0s 401ms/step - loss: 0.5713 - binary_accuracy: 1.0000
# Epoch 1/1
# 1/1 [==============================] - 1s 528ms/step - loss: 0.5706 - binary_accuracy: 1.0000

# %% [markdown]
# Evaluation
# ========

# %%
for trheshold in np.arange(0.1, 0.9, 0.1):
  print("THRESHOLD: {}\n**********************".format(trheshold))
  from sklearn.metrics import classification_report
  predictions_list = []
  for i, net_model in enumerate(model_list):
    print("\n\n********************************************\n")
    print(network_names[i])
    model_path = SST_HOME+"DL/models/E/" + network_names[i]
    try:
      net_model = load_model(model_path)
    except ValueError:
      print("The model {} was not loaded correctly".format(name))
      continue
    except OSError:
      print("The model {} does not exist".format(name))
      continue

    predictions = []
    for subject in test_x_subjects:
      predictions.append(net_model.predict(np.array([subject])))

    predictions = np.array([0 if prediction < trheshold else 1 for prediction in predictions])
    predictions_list.append(predictions)
    # measuring performance on test set
    cr=classification_report(test_y_subjects, predictions)
    print(cr)
    # Release memory
    K.clear_session()
# Out:
# THRESHOLD: 0.1
# **********************
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_1
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       279
#            1       0.13      1.00      0.23        41
#
#    micro avg       0.13      0.13      0.13       320
#    macro avg       0.06      0.50      0.11       320
# weighted avg       0.02      0.13      0.03       320
#
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       279
#            1       0.13      1.00      0.23        41
#
#    micro avg       0.13      0.13      0.13       320
#    macro avg       0.06      0.50      0.11       320
# weighted avg       0.02      0.13      0.03       320
#
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_LSTM_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       279
#            1       0.13      1.00      0.23        41
#
#    micro avg       0.13      0.13      0.13       320
#    macro avg       0.06      0.50      0.11       320
# weighted avg       0.02      0.13      0.03       320
#
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_LSTM_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       279
#            1       0.13      1.00      0.23        41
#
#    micro avg       0.13      0.13      0.13       320
#    macro avg       0.06      0.50      0.11       320
# weighted avg       0.02      0.13      0.03       320
#
# THRESHOLD: 0.2
# **********************
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       279
#            1       0.13      1.00      0.23        41
#
#    micro avg       0.13      0.13      0.13       320
#    macro avg       0.06      0.50      0.11       320
# weighted avg       0.02      0.13      0.03       320
#
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       279
#            1       0.13      1.00      0.23        41
#
#    micro avg       0.13      0.13      0.13       320
#    macro avg       0.06      0.50      0.11       320
# weighted avg       0.02      0.13      0.03       320
#
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_LSTM_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       279
#            1       0.13      1.00      0.23        41
#
#    micro avg       0.13      0.13      0.13       320
#    macro avg       0.06      0.50      0.11       320
# weighted avg       0.02      0.13      0.03       320
#
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_LSTM_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       279
#            1       0.13      1.00      0.23        41
#
#    micro avg       0.13      0.13      0.13       320
#    macro avg       0.06      0.50      0.11       320
# weighted avg       0.02      0.13      0.03       320
#
# THRESHOLD: 0.30000000000000004
# **********************
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       279
#            1       0.13      1.00      0.23        41
#
#    micro avg       0.13      0.13      0.13       320
#    macro avg       0.06      0.50      0.11       320
# weighted avg       0.02      0.13      0.03       320
#
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       279
#            1       0.13      1.00      0.23        41
#
#    micro avg       0.13      0.13      0.13       320
#    macro avg       0.06      0.50      0.11       320
# weighted avg       0.02      0.13      0.03       320
#
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_LSTM_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       279
#            1       0.13      1.00      0.23        41
#
#    micro avg       0.13      0.13      0.13       320
#    macro avg       0.06      0.50      0.11       320
# weighted avg       0.02      0.13      0.03       320
#
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_LSTM_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       279
#            1       0.13      1.00      0.23        41
#
#    micro avg       0.13      0.13      0.13       320
#    macro avg       0.06      0.50      0.11       320
# weighted avg       0.02      0.13      0.03       320
#
# THRESHOLD: 0.4
# **********************
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       279
#            1       0.13      1.00      0.23        41
#
#    micro avg       0.13      0.13      0.13       320
#    macro avg       0.06      0.50      0.11       320
# weighted avg       0.02      0.13      0.03       320
#
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       279
#            1       0.13      1.00      0.23        41
#
#    micro avg       0.13      0.13      0.13       320
#    macro avg       0.06      0.50      0.11       320
# weighted avg       0.02      0.13      0.03       320
#
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_LSTM_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       279
#            1       0.13      1.00      0.23        41
#
#    micro avg       0.13      0.13      0.13       320
#    macro avg       0.06      0.50      0.11       320
# weighted avg       0.02      0.13      0.03       320
#
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_LSTM_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       279
#            1       0.13      1.00      0.23        41
#
#    micro avg       0.13      0.13      0.13       320
#    macro avg       0.06      0.50      0.11       320
# weighted avg       0.02      0.13      0.03       320
#
# THRESHOLD: 0.5
# **********************
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       279
#            1       0.13      1.00      0.23        41
#
#    micro avg       0.13      0.13      0.13       320
#    macro avg       0.06      0.50      0.11       320
# weighted avg       0.02      0.13      0.03       320
#
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       279
#            1       0.13      1.00      0.23        41
#
#    micro avg       0.13      0.13      0.13       320
#    macro avg       0.06      0.50      0.11       320
# weighted avg       0.02      0.13      0.03       320
#
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_LSTM_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       279
#            1       0.13      1.00      0.23        41
#
#    micro avg       0.13      0.13      0.13       320
#    macro avg       0.06      0.50      0.11       320
# weighted avg       0.02      0.13      0.03       320
#
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_LSTM_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       279
#            1       0.13      1.00      0.23        41
#
#    micro avg       0.13      0.13      0.13       320
#    macro avg       0.06      0.50      0.11       320
# weighted avg       0.02      0.13      0.03       320
#
# THRESHOLD: 0.6
# **********************
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92       279
#            1       0.35      0.17      0.23        41
#
#    micro avg       0.85      0.85      0.85       320
#    macro avg       0.62      0.56      0.57       320
# weighted avg       0.82      0.85      0.83       320
#
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92       279
#            1       0.33      0.17      0.23        41
#
#    micro avg       0.85      0.85      0.85       320
#    macro avg       0.61      0.56      0.57       320
# weighted avg       0.82      0.85      0.83       320
#
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_LSTM_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93       279
#            1       0.38      0.07      0.12        41
#
#    micro avg       0.87      0.87      0.87       320
#    macro avg       0.63      0.53      0.52       320
# weighted avg       0.81      0.87      0.82       320
#
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_LSTM_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94       279
#            1       1.00      0.07      0.14        41
#
#    micro avg       0.88      0.88      0.88       320
#    macro avg       0.94      0.54      0.54       320
# weighted avg       0.90      0.88      0.83       320
#
# THRESHOLD: 0.7000000000000001
# **********************
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.87      0.99      0.93       279
#            1       0.00      0.00      0.00        41
#
#    micro avg       0.87      0.87      0.87       320
#    macro avg       0.44      0.50      0.46       320
# weighted avg       0.76      0.87      0.81       320
#
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       279
#            1       0.00      0.00      0.00        41
#
#    micro avg       0.87      0.87      0.87       320
#    macro avg       0.44      0.50      0.47       320
# weighted avg       0.76      0.87      0.81       320
#
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_LSTM_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       279
#            1       0.00      0.00      0.00        41
#
#    micro avg       0.87      0.87      0.87       320
#    macro avg       0.44      0.50      0.47       320
# weighted avg       0.76      0.87      0.81       320
#
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_LSTM_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       279
#            1       1.00      0.02      0.05        41
#
#    micro avg       0.88      0.88      0.88       320
#    macro avg       0.94      0.51      0.49       320
# weighted avg       0.89      0.88      0.82       320
#
# THRESHOLD: 0.8
# **********************
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       279
#            1       0.00      0.00      0.00        41
#
#    micro avg       0.87      0.87      0.87       320
#    macro avg       0.44      0.50      0.47       320
# weighted avg       0.76      0.87      0.81       320
#
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       279
#            1       0.00      0.00      0.00        41
#
#    micro avg       0.87      0.87      0.87       320
#    macro avg       0.44      0.50      0.47       320
# weighted avg       0.76      0.87      0.81       320
#
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_LSTM_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       279
#            1       0.00      0.00      0.00        41
#
#    micro avg       0.87      0.87      0.87       320
#    macro avg       0.44      0.50      0.47       320
# weighted avg       0.76      0.87      0.81       320
#
#
#
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_LSTM_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       279
#            1       0.00      0.00      0.00        41
#
#    micro avg       0.87      0.87      0.87       320
#    macro avg       0.44      0.50      0.47       320
# weighted avg       0.76      0.87      0.81       320

# %%
from keras.models import load_model
network_names = [""]
for trheshold in np.arange(0.1, 1.1, 0.1):
# trheshold = 0.2
  print("THRESHOLD: {}\n**********************".format(trheshold))
  from sklearn.metrics import classification_report
  predictions_list = []
  i = 0
  network_names[i] = "Copia de load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1"
  
  print(network_names[i])
  model_path = SST_HOME+"DL/models/E/best_models/" + network_names[i]
  try:
    net_model = load_model(model_path)
  except ValueError:
    print("The model {} was not loaded correctly".format(name))
    continue
  except OSError:
    print("The model does not exist")
    continue
  predictions = []
  for subject in test_x_subjects:
    predictions.append(net_model.predict(np.array([subject])))

  predictions = np.array([0 if prediction < trheshold else 1 for prediction in predictions])
  predictions_list.append(predictions)
  # measuring performance on test set
  cr=classification_report(test_y_subjects, predictions)
  print(cr)
  # Release memory
  K.clear_session()
# Out:
# THRESHOLD: 0.1
# **********************
# Copia de load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       279
#            1       0.13      1.00      0.23        41
#
#     accuracy                           0.13       320
#    macro avg       0.06      0.50      0.11       320
# weighted avg       0.02      0.13      0.03       320
#
# THRESHOLD: 0.2
# **********************
# Copia de load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       279
#            1       0.13      1.00      0.23        41
#
#     accuracy                           0.13       320
#    macro avg       0.06      0.50      0.11       320
# weighted avg       0.02      0.13      0.03       320
#
# THRESHOLD: 0.30000000000000004
# **********************
# Copia de load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       279
#            1       0.13      1.00      0.23        41
#
#     accuracy                           0.13       320
#    macro avg       0.06      0.50      0.11       320
# weighted avg       0.02      0.13      0.03       320
#
# THRESHOLD: 0.4
# **********************
# Copia de load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       279
#            1       0.13      1.00      0.23        41
#
#     accuracy                           0.13       320
#    macro avg       0.06      0.50      0.11       320
# weighted avg       0.02      0.13      0.03       320
#
# THRESHOLD: 0.5
# **********************
# Copia de load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       279
#            1       0.13      1.00      0.23        41
#
#     accuracy                           0.13       320
#    macro avg       0.06      0.50      0.11       320
# weighted avg       0.02      0.13      0.03       320
#
# THRESHOLD: 0.6
# **********************
# Copia de load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92       279
#            1       0.33      0.17      0.23        41
#
#     accuracy                           0.85       320
#    macro avg       0.61      0.56      0.57       320
# weighted avg       0.82      0.85      0.83       320
#
# THRESHOLD: 0.7000000000000001
# **********************
# Copia de load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       279
#            1       0.00      0.00      0.00        41
#
#     accuracy                           0.87       320
#    macro avg       0.44      0.50      0.47       320
# weighted avg       0.76      0.87      0.81       320
#
# THRESHOLD: 0.8
# **********************
# Copia de load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       279
#            1       0.00      0.00      0.00        41
#
#     accuracy                           0.87       320
#    macro avg       0.44      0.50      0.47       320
# weighted avg       0.76      0.87      0.81       320
#
# THRESHOLD: 0.9
# **********************
# Copia de load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       279
#            1       0.00      0.00      0.00        41
#
#     accuracy                           0.87       320
#    macro avg       0.44      0.50      0.47       320
# weighted avg       0.76      0.87      0.81       320
#
# THRESHOLD: 1.0
# **********************
# Copia de load_emb_False_num_classes_1_emb_size_None_trainable_emb_False_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_False_attention_False_dropout_0.5_dnn_size_32_batch_size_1
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       279
#            1       0.00      0.00      0.00        41
#
#     accuracy                           0.87       320
#    macro avg       0.44      0.50      0.47       320
# weighted avg       0.76      0.87      0.81       320
