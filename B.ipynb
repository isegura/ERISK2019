# %% [markdown]
# B MODEL
# ========
#
# This model is the simple approach of trying to classify the different records by each subject. It simply gets every ocurrence from the subject as an input and tries to label them.
#
# The different writtings are put trhough an TF-IDF tokenizer, this will be the input to the next stages.
#
# The tokenized data is then put trough a Neural Network model, which will learn from it to later classify the server occurrences.

# %% [markdown]
# Initialization of the Environment
# ==========================

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import collections
import tensorflow as tf
import os

np.random.seed(1)
tf.set_random_seed(2)

# %% [markdown]
# Load Data
# ========

# %%
import xml.etree.ElementTree as ET
import csv
import pandas as pd

# %%
SST_HOME='drive/My Drive/Colab Notebooks/Erisk2019/'
path_train=SST_HOME+'datas/training data - t1/2018 train/train_B.csv'
path_test=SST_HOME+'datas/training data - t1/2018 test/test_B.csv'

# %%
def listdir_fulllpath(d):
  return [os.path.join(d, f) for f in os.listdir(d)]

# %%
def parse_subject(path_xml):
  """
  This function will take the xmls return a pandas df.
  """
  tree = ET.parse(path_xml)
  root = tree.getroot()
  
  subject_id = root.find('ID').text
  writings = []
  # Read the xml
  writing_data = {}
  writing_data['ID'] = subject_id
  writing_data['TEXT'] = ""
  
    # Read the xml
  for writing in root.findall('WRITING'):
    writing_data['TEXT'] = writing_data['TEXT'] + " " + writing.find('TEXT').text
  
  writings.append(writing_data)
    
  df = pd.DataFrame(writings)
  # If the record has no id or date return none
  try:
    df = df.set_index(['ID'])
  except:
    return None
  
  return df


def parse_folder(path_folder):
  """
  This function will parse a whole folder worth of records.
  
  Returns the records as a csv.
  """
  # Look for all the files in the directory
  files = []
  for f in os.listdir(path_folder):
      file_path = os.path.join(path_folder, f)
      if os.path.isfile(file_path):
        files.append(file_path)
  
  # Parse the xmls to pandas dataframes
  frames = [parse_subject(f) for f in files]
  
  # Merge the frames
  return pd.concat(frames)
  
def records_to_csv(path_records, path_csv, load=False):
  """
  This function will parse all the records into a csv
  """
  if load:
    if os.path.exists(path_csv):
      return pd.read_csv(path_csv).set_index(['ID'])
    else:
      print("File not found, can't load")
    
  
  frames = []
  test = False
  for f in listdir_fulllpath(path_records):
    
    # check if it is a test folder.
    if 'test' in f:
      test = True
      
    if os.path.isdir(f):
      for j in listdir_fulllpath(f):
        if os.path.isdir(j):
          frames.append(parse_folder(j))
          
  df = pd.concat(frames).sort_index()
  
  with open(path_records + 'risk_golden_truth.txt' if not test else path_records + 'risk-golden-truth-test.txt') as gt:
    df["LABEL"] = np.nan
    for line in gt:
      
      # The file ends with a newline, dont really know why
      if line == '\n':
        break
      
      rec_id, value = line.split()

      df.loc[rec_id, 'LABEL'] = value
      
  df.to_csv(path_csv)
  return df

# %%
print('started')
train_df = records_to_csv(SST_HOME+'datas/training data - t1/2018 train/', path_train, load=True)
print('completed train')
test_df = records_to_csv(SST_HOME+'datas/training data - t1/2018 test/', path_test, load=True)
print('completed test')
# Out:
# started
# completed train
# completed test

# %%
print(len(test_df), len(train_df))
# Out:
# 3200 1520

# %%
train_df.columns
# Out:
# Index(['TEXT', 'LABEL'], dtype='object')

# %%
train_x = [text for text in train_df["TEXT"].values]
train_y = train_df["LABEL"].values

test_x = [text for text in test_df["TEXT"].values]
test_y = test_df["LABEL"].values

# %%
train_balance = collections.Counter(train_y)
test_balance = collections.Counter(test_y)

print(train_balance)
print(test_balance)
# Out:
# Counter({0: 1320, 1: 200})
# Counter({0: 2790, 1: 410})

# %% [markdown]
# Tokenizing the texts
# ================

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from sklearn.feature_extraction.text import TfidfVectorizer

import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

stop_words=stopwords.words('english')
# Define maximum vocabulary length
MAX_WORDS = 5000
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# We are using this function to clean the test set
def tokenize_clean_text(text, tfidf=True, tokenizer=None, max_length=None, max_words=MAX_WORDS):
  """
  This function is in charge of tokenizing the text it is given. It also cleans
  the text from stop-words, punctuation, and gives a special token to numbers.
  
  :param text: The texts to tokenize in a bidimensional python array.
  
  :returns: The tokenized and cleaned text in a bidimensional python array.
            The tokenizer used to preprocess the text.
            The maximum length used for padding.
  """   
  # set [removed] as a special token
  text_removed = [str(t).replace("[removed]", "R3MOV3D") for t in text]

  # We remove the numbers
  cropped_numbers_text = [" ".join([word if not word.isdigit() else "" for word in sentence.split()])
                               for sentence in text_removed]
                          
  # Delete stopwords as well as every word less than 3 chars.
  cropped_numbers_stopw_text = [" ".join([word if not (word in stop_words or len(word) <= 3) else "" 
                                          for word in sentence.split()])
                                    for sentence in cropped_numbers_text]
    
  if tfidf:
    vec = TfidfVectorizer(max_features=max_words)
    tfidf_mat = vec.fit_transform(cropped_numbers_stopw_text).toarray()
    tfid_words = vec.get_feature_names()

    cropped_numbers_stopw_tfidf_text = [" ".join([word if word in tfid_words else ""
                                            for word in sentence.split()])
                                            for sentence in cropped_numbers_stopw_text]
                          
  if tokenizer is None:
    tokenizer = Tokenizer(num_words=max_words) # They use 5k words too
    tokenizer.fit_on_texts(cropped_numbers_stopw_tfidf_text if tfidf else cropped_numbers_stopw_text)
  # We tokenize the sentences
  tokenized_text = tokenizer.texts_to_sequences(cropped_numbers_stopw_tfidf_text if tfidf else cropped_numbers_stopw_text)
  
  if max_length == None:
    max_length = 0
    for sentence in tokenized_text:
      max_length = max_length if len(sentence) < max_length else len(sentence)
  
  # Now we return the padded the sequences.
  return pad_sequences(tokenized_text, max_length), tokenizer, max_length, cropped_numbers_stopw_tfidf_text if tfidf else cropped_numbers_stopw_text

# %%
train_x_token, tokenizer, max_length, train_x_clean = tokenize_clean_text(train_x) 
test_x_token, _, _, test_x_clean = tokenize_clean_text(test_x, tokenizer=tokenizer)

# %%
token_index = np.unique(train_x_token)

# %%
max_words = len(token_index)

# %%
import matplotlib.pyplot as plt

lengths  = np.array([len(sentence.split()) for sentence in test_x_clean if len(sentence.split()) < 40000])
plt.hist(lengths, bins=100, cumulative = True)
plt.title("TFIDF text")
plt.xlabel("Length")
plt.ylabel("Ocurrences")
plt.savefig(SST_HOME + 'b_text_hist.eps', metadata="eps")

# %%
# the length will be set to 350
max_length = 350
train_x_token = train_x_token[:,-max_length:]
test_x_token = test_x_token[:,-max_length:]

# %% [markdown]
# Experiments Configuration
# =====================

# %%
from keras.layers import LSTM, GRU

# %%
load_emb = [False]
num_classes = [None]
emb_size = [300]
trainable_emb = [True]
cnn_size = [[None]]# [[64],[64, 64], [128], [128, 128]]
cnn_filter = [[3]]
rnn_size = [[64], [64, 64], [128], [128, 128]]
cell_type = [LSTM, GRU]
bidirectional = [True, False]
attention = [False]
dropout = [0.5]
dnn_size = [[32], [64], [128]]
batch_size = [1024]

indexes = ["load_emb", "emb_size", "trainable_emb", "cnn_size", "cnn_filter", "rnn_size", "cell_type", "bidirectional", "attention", "dropout", "dnn_size", "batch_size"]
param   = [load_emb, emb_size, trainable_emb, cnn_size, cnn_filter, rnn_size, cell_type, bidirectional, attention, dropout, dnn_size, batch_size]

# %%
import itertools

def combine_params(param, indexes):
  """
  This function is in charge of combining the parameters. This way we can perform a grid search automatically.
  
  Inputs: The array of different parameters, and the indexes for them.
  
  Outputs: The dictionary of different configurations made.
  """
  combinations = list(itertools.product(*param))
  param_combinations = [{k:v for k, v in zip(indexes, combination)}  for combination in combinations]
  for p in param_combinations:
    # The embeddings size must adapt to the embeddings loaded.
    if p["load_emb"]:
      p["emb_size"] = None
    else:
      p["embedding_matrix"] = None
  return param_combinations

# %%
network_parameters = combine_params(param, indexes)

# %%
# We change the number of classes automatically
for p in network_parameters:
  p["max_length"] = max_length
  p["max_words"] = max_words
  try:
    p["num_classes"] = train_y.shape[1]
  except IndexError:
    p["num_classes"] = 1

# %% [markdown]
# # Load the embeddings
#
# In this step, we load the word embeddings from the wikipedia, pubmed and PMC. Then we filter them adapting to the words we have in our dataset. This is, if the word appears in the pubmed we take its weights, which are set to 0 otherwise.

# %%
# seemingly gensim is not installed in google colab
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.16.4)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.3.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.8.4)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.12.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim) (1.9.167)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim) (2.21.0)
# Requirement already satisfied: boto>=2.32 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim) (2.49.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim) (0.9.4)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim) (0.2.1)
# Requirement already satisfied: botocore<1.13.0,>=1.12.167 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim) (1.12.167)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (2019.3.9)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (3.0.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1; python_version >= "2.7" in /usr/local/lib/python3.6/dist-packages (from botocore<1.13.0,>=1.12.167->boto3->smart-open>=1.2.1->gensim) (2.5.3)
# Requirement already satisfied: docutils>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.13.0,>=1.12.167->boto3->smart-open>=1.2.1->gensim) (0.14)

# %%
from gensim.models.keyedvectors import KeyedVectors

#TODO
# Get social media embeddings

PATH_W2V = SST_HOME + "DL/wikipedia-pubmed-and-PMC-w2v.bin"

# %%
def load_W2V_model(path, binary):
    model = KeyedVectors.load_word2vec_format(path, binary=binary)
    print("Binary : {}".format(binary))
    print("Loaded W2V model")
    return model
  
def generate_embedding_weigths(word_index, max_words, model, binary=False):
  # We initialize the embd matrix as random
  # embedding_matrix = np.zeros((max_words, model.vector_size), dtype=np.float32)
  embedding_matrix = np.random.rand(max_words, model.vector_size)
  hit = 0
  for word, i in word_index.items():
    if i >= max_words:
        break
    if word in model:
        # words not found in embedding index will be randomly initialized.
        embedding_matrix[i] = model[word]
        hit += 1
  print("Hits: {}\nTotal: {}".format(hit, i))

  return embedding_matrix

# %%
 
if any([p["load_emb"] for p in network_parameters]):
  binary = True if PATH_W2V[-3:]=="bin" else False
  if not 'model' in locals():
    model = load_W2V_model(PATH_W2V, binary)
  # Generate the weights matrix

  if any([p["load_emb"] for p in network_parameters]):
    embedding_matrix = generate_embedding_weigths(tokenizer.word_index, p["max_words"], model, binary=binary)

for p in network_parameters:
  if p["load_emb"]: 
    p["emb_size"] = model.vector_size
    p["embedding_matrix"] = embedding_matrix

# %% [markdown]
# Neural networks
# =============

# %%
import keras
from keras import backend as K
from keras.models import Model
from keras.layers import Dense, Activation, Embedding, Dropout, Input
from keras.layers import Lambda, Flatten, RepeatVector, Permute, Multiply
from keras.layers import LSTM, GRU, Bidirectional, BatchNormalization
from keras.layers import Conv1D, MaxPooling1D, Concatenate

from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.losses import binary_crossentropy
from keras.optimizers import RMSprop, Adam

# %% [markdown]
# # **TensorBoard**
# TensorBoard is a great tool for DL visualization. It shows the evolution of metrics during the training phase, as well as the weights, distributions, and even the graph of the neural net.
#
# We will be using tensorboardcolab in order to run a
# TensorBoard instance. This will initialize a ngrok machine and launch TensorBoard for us to see.
#
# TensorBoard will be accesible by the url

# %%
# We install tensorboard colab in case we don't have it already.
# !pip install tensorboardcolab
# Out:
# Requirement already satisfied: tensorboardcolab in /usr/local/lib/python3.6/dist-packages (0.0.22)

# %%
import tensorboardcolab as tb

tbc=tb.TensorBoardColab()
# Out:
# Wait for 8 seconds...
# TensorBoard link:
# https://ed254f03.ngrok.io

# %% [markdown]
# Neural Network
# =============

# %%
def add_embeddings(z, load, size, trainable, vocab_size, max_length, embedding_matrix): 
  """
  This method adds embeddings to the network.
  
  Returns the net with the embeddings added.
  """
  if load:
    z = Embedding(vocab_size, size, input_length=max_length, weights=[embedding_matrix], trainable=trainable)(z)
  else:
    z = Embedding(vocab_size, size, input_length=max_length)(z)
    
  return z

def add_cnn(z, size, filter_sizes, flatten):
  """
  This method adds the CNN layers to the network.
  
  Returns the net with the CNN layers.
  """
  conv_blocks = []
  for filter_size in filter_sizes:
    if filter_size is None:
      return z
    conv = None
    for i, cnn_layer in enumerate(size):
      if cnn_layer is None:
        return z
      conv = Conv1D(cnn_layer, filter_size, padding='valid', activation='relu', strides=1)(z if conv is None else conv)
      # if (i + 1)  % 2 == 0:
      conv = MaxPooling1D(pool_size=filter_size)(conv)        
      
    if flatten:
      conv = Flatten()(conv)
    conv_blocks.append(conv)         
 
  z = Concatenate()(conv_blocks) if len(conv_blocks) > 1 else conv_blocks[0]
  
  return z

def add_rnn(z, size, bidirectional, cell_type, attention):
  """
  This method adds the RNN layers to the network. It also adds an attention layer if intended.
  
  Returns the net with the RNN & Attention added.
  """
  for i, rsz in enumerate(size):
    if rsz is None:
      return z
    if not bidirectional:
      if i < len(size) - 1:
        z = cell_type(rsz, return_sequences=True)(z)
      else:
        z = cell_type(rsz, return_sequences=attention)(z)
    else:
      if i < len(size) - 1:
        z = Bidirectional(cell_type(rsz, return_sequences=True))(z)
      else:
        z = Bidirectional(cell_type(rsz, return_sequences=attention))(z)

  if attention:
    z = add_attention(z)

  return z

def add_dnn(z, size, dropout, activation="relu"):
  """
  This method adds the DNN layers to the network.
  
  Returns the net with the DNN layers added.
  """
  for fsz in size:
    if fsz is None:
      return z

    z = Dense(fsz, activation=activation)(z)
    z = Dropout(dropout)(z)
    
  return z

def add_attention(activations):
  """
  This method adds an attention layer.
  
  Returns the model with the attention layer.
  """
  
  size =  K.int_shape(activations)[-1]
  attention = BatchNormalization()(activations)
  attention = Dense(1, activation='tanh')(attention)
  attention = Flatten()(attention)
  attention = Activation('softmax')(attention)
  attention = RepeatVector(size)(attention)
  attention = Permute([2, 1])(attention)
  
  z = Multiply()([activations, attention])
  z = Lambda(lambda xin: K.sum(xin, axis=-2), output_shape=(size,))(z)

  return z

# %%
def create_model(params):
  """
  This method creates a network model with the parameters given.
  
  Returns the uncompiled model.
  """
  inputs = Input(name='inputs',shape=(params["max_length"],))
  
  z = add_embeddings(inputs, params["load_emb"], params["emb_size"], params["trainable_emb"], params["max_words"] ,params["max_length"], params["embedding_matrix"])
  
  z = add_cnn(z, params["cnn_size"], params["cnn_filter"], [None] == params["rnn_size"])
  
  z = add_rnn(z, params["rnn_size"], params["bidirectional"], params["cell_type"], params["attention"])
  
  # This enters the stage if nor cnn nor rnn are used
  if len(K.int_shape(z)) > 2:
      z = Flatten()(z)
      
  z = add_dnn(z, params["dnn_size"], params["dropout"])
  
  outputs = Dense(params["num_classes"], activation='sigmoid', name='output_layer')(z)
  
  net_model = Model(inputs=inputs,outputs=outputs)
  
  return net_model

# %%
def create_models(network_parameters, verbose=False):
  model_list = []
  for net_p in network_parameters:
    m = create_model(net_p)
    m.compile(loss='binary_crossentropy', optimizer='adam', metrics=['binary_accuracy'])
    model_list.append(m)
    
    if verbose:
      m.summary()
      
  return model_list

# %%
model_list = create_models(network_parameters, verbose=True)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0620 11:21:18.967480 139777107322752 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0620 11:21:18.980245 139777107322752 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0620 11:21:18.981601 139777107322752 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0620 11:21:19.590282 139777107322752 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0620 11:21:19.599559 139777107322752 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0620 11:21:19.625274 139777107322752 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0620 11:21:19.646716 139777107322752 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0620 11:21:19.652743 139777107322752 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 1000, 300)         1355400
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 128)               186880
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 33
# =================================================================
# Total params: 1,546,441
# Trainable params: 1,546,441
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_2 (Embedding)      (None, 1000, 300)         1355400
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 128)               186880
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 65
# =================================================================
# Total params: 1,550,601
# Trainable params: 1,550,601
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_3 (Embedding)      (None, 1000, 300)         1355400
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 128)               186880
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 129
# =================================================================
# Total params: 1,558,921
# Trainable params: 1,558,921
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_4 (Embedding)      (None, 1000, 300)         1355400
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 64)                93440
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 32)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 33
# =================================================================
# Total params: 1,450,953
# Trainable params: 1,450,953
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_5 (Embedding)      (None, 1000, 300)         1355400
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 64)                93440
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 65
# =================================================================
# Total params: 1,453,065
# Trainable params: 1,453,065
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_6 (Embedding)      (None, 1000, 300)         1355400
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 64)                93440
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 129
# =================================================================
# Total params: 1,457,289
# Trainable params: 1,457,289
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_7 (Embedding)      (None, 1000, 300)         1355400
# _________________________________________________________________
# bidirectional_4 (Bidirection (None, 128)               140160
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 32)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 33
# =================================================================
# Total params: 1,499,721
# Trainable params: 1,499,721
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_8 (Embedding)      (None, 1000, 300)         1355400
# _________________________________________________________________
# bidirectional_5 (Bidirection (None, 128)               140160
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 65
# =================================================================
# Total params: 1,503,881
# Trainable params: 1,503,881
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_9 (Embedding)      (None, 1000, 300)         1355400
# _________________________________________________________________
# bidirectional_6 (Bidirection (None, 128)               140160
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 129
# =================================================================
# Total params: 1,512,201
# Trainable params: 1,512,201
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_10 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# gru_4 (GRU)                  (None, 64)                70080
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 32)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 33
# =================================================================
# Total params: 1,427,593
# Trainable params: 1,427,593
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_11 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# gru_5 (GRU)                  (None, 64)                70080
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 64)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 65
# =================================================================
# Total params: 1,429,705
# Trainable params: 1,429,705
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_12 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# gru_6 (GRU)                  (None, 64)                70080
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 128)               0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 129
# =================================================================
# Total params: 1,433,929
# Trainable params: 1,433,929
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_13 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# bidirectional_7 (Bidirection (None, 1000, 128)         186880
# _________________________________________________________________
# bidirectional_8 (Bidirection (None, 128)               98816
# _________________________________________________________________
# dense_13 (Dense)             (None, 32)                4128
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 32)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 33
# =================================================================
# Total params: 1,645,257
# Trainable params: 1,645,257
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_14 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# bidirectional_9 (Bidirection (None, 1000, 128)         186880
# _________________________________________________________________
# bidirectional_10 (Bidirectio (None, 128)               98816
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 64)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 65
# =================================================================
# Total params: 1,649,417
# Trainable params: 1,649,417
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_15 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# bidirectional_11 (Bidirectio (None, 1000, 128)         186880
# _________________________________________________________________
# bidirectional_12 (Bidirectio (None, 128)               98816
# _________________________________________________________________
# dense_15 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 128)               0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 129
# =================================================================
# Total params: 1,657,737
# Trainable params: 1,657,737
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_16 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 1000, 64)          93440
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 64)                33024
# _________________________________________________________________
# dense_16 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 32)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 33
# =================================================================
# Total params: 1,483,977
# Trainable params: 1,483,977
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_17 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 1000, 64)          93440
# _________________________________________________________________
# lstm_16 (LSTM)               (None, 64)                33024
# _________________________________________________________________
# dense_17 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 64)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 65
# =================================================================
# Total params: 1,486,089
# Trainable params: 1,486,089
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_18 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 1000, 64)          93440
# _________________________________________________________________
# lstm_18 (LSTM)               (None, 64)                33024
# _________________________________________________________________
# dense_18 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 128)               0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 129
# =================================================================
# Total params: 1,490,313
# Trainable params: 1,490,313
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_19 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# bidirectional_13 (Bidirectio (None, 1000, 128)         140160
# _________________________________________________________________
# bidirectional_14 (Bidirectio (None, 128)               74112
# _________________________________________________________________
# dense_19 (Dense)             (None, 32)                4128
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 32)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 33
# =================================================================
# Total params: 1,573,833
# Trainable params: 1,573,833
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_20 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# bidirectional_15 (Bidirectio (None, 1000, 128)         140160
# _________________________________________________________________
# bidirectional_16 (Bidirectio (None, 128)               74112
# _________________________________________________________________
# dense_20 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 64)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 65
# =================================================================
# Total params: 1,577,993
# Trainable params: 1,577,993
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_21 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# bidirectional_17 (Bidirectio (None, 1000, 128)         140160
# _________________________________________________________________
# bidirectional_18 (Bidirectio (None, 128)               74112
# _________________________________________________________________
# dense_21 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 128)               0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 129
# =================================================================
# Total params: 1,586,313
# Trainable params: 1,586,313
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_22 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# gru_13 (GRU)                 (None, 1000, 64)          70080
# _________________________________________________________________
# gru_14 (GRU)                 (None, 64)                24768
# _________________________________________________________________
# dense_22 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 32)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 33
# =================================================================
# Total params: 1,452,361
# Trainable params: 1,452,361
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_23 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# gru_15 (GRU)                 (None, 1000, 64)          70080
# _________________________________________________________________
# gru_16 (GRU)                 (None, 64)                24768
# _________________________________________________________________
# dense_23 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 64)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 65
# =================================================================
# Total params: 1,454,473
# Trainable params: 1,454,473
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_24 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# gru_17 (GRU)                 (None, 1000, 64)          70080
# _________________________________________________________________
# gru_18 (GRU)                 (None, 64)                24768
# _________________________________________________________________
# dense_24 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 128)               0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 129
# =================================================================
# Total params: 1,458,697
# Trainable params: 1,458,697
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_25 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# bidirectional_19 (Bidirectio (None, 256)               439296
# _________________________________________________________________
# dense_25 (Dense)             (None, 32)                8224
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 32)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 33
# =================================================================
# Total params: 1,802,953
# Trainable params: 1,802,953
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_26 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# bidirectional_20 (Bidirectio (None, 256)               439296
# _________________________________________________________________
# dense_26 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 64)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 65
# =================================================================
# Total params: 1,811,209
# Trainable params: 1,811,209
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_27 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# bidirectional_21 (Bidirectio (None, 256)               439296
# _________________________________________________________________
# dense_27 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 128)               0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 129
# =================================================================
# Total params: 1,827,721
# Trainable params: 1,827,721
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_28 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# lstm_22 (LSTM)               (None, 128)               219648
# _________________________________________________________________
# dense_28 (Dense)             (None, 32)                4128
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 32)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 33
# =================================================================
# Total params: 1,579,209
# Trainable params: 1,579,209
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_29 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# lstm_23 (LSTM)               (None, 128)               219648
# _________________________________________________________________
# dense_29 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 64)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 65
# =================================================================
# Total params: 1,583,369
# Trainable params: 1,583,369
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_30 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# lstm_24 (LSTM)               (None, 128)               219648
# _________________________________________________________________
# dense_30 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 128)               0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 129
# =================================================================
# Total params: 1,591,689
# Trainable params: 1,591,689
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_31 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# bidirectional_22 (Bidirectio (None, 256)               329472
# _________________________________________________________________
# dense_31 (Dense)             (None, 32)                8224
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 32)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 33
# =================================================================
# Total params: 1,693,129
# Trainable params: 1,693,129
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_32 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# bidirectional_23 (Bidirectio (None, 256)               329472
# _________________________________________________________________
# dense_32 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 64)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 65
# =================================================================
# Total params: 1,701,385
# Trainable params: 1,701,385
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_33 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# bidirectional_24 (Bidirectio (None, 256)               329472
# _________________________________________________________________
# dense_33 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 128)               0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 129
# =================================================================
# Total params: 1,717,897
# Trainable params: 1,717,897
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_34 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# gru_22 (GRU)                 (None, 128)               164736
# _________________________________________________________________
# dense_34 (Dense)             (None, 32)                4128
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 32)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 33
# =================================================================
# Total params: 1,524,297
# Trainable params: 1,524,297
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_35 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# gru_23 (GRU)                 (None, 128)               164736
# _________________________________________________________________
# dense_35 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 64)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 65
# =================================================================
# Total params: 1,528,457
# Trainable params: 1,528,457
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_36 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# gru_24 (GRU)                 (None, 128)               164736
# _________________________________________________________________
# dense_36 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 128)               0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 129
# =================================================================
# Total params: 1,536,777
# Trainable params: 1,536,777
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_37 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# bidirectional_25 (Bidirectio (None, 1000, 256)         439296
# _________________________________________________________________
# bidirectional_26 (Bidirectio (None, 256)               394240
# _________________________________________________________________
# dense_37 (Dense)             (None, 32)                8224
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 32)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 33
# =================================================================
# Total params: 2,197,193
# Trainable params: 2,197,193
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_38 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# bidirectional_27 (Bidirectio (None, 1000, 256)         439296
# _________________________________________________________________
# bidirectional_28 (Bidirectio (None, 256)               394240
# _________________________________________________________________
# dense_38 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 64)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 65
# =================================================================
# Total params: 2,205,449
# Trainable params: 2,205,449
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_39 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# bidirectional_29 (Bidirectio (None, 1000, 256)         439296
# _________________________________________________________________
# bidirectional_30 (Bidirectio (None, 256)               394240
# _________________________________________________________________
# dense_39 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 128)               0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 129
# =================================================================
# Total params: 2,221,961
# Trainable params: 2,221,961
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_40 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# lstm_31 (LSTM)               (None, 1000, 128)         219648
# _________________________________________________________________
# lstm_32 (LSTM)               (None, 128)               131584
# _________________________________________________________________
# dense_40 (Dense)             (None, 32)                4128
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 32)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 33
# =================================================================
# Total params: 1,710,793
# Trainable params: 1,710,793
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_41 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# lstm_33 (LSTM)               (None, 1000, 128)         219648
# _________________________________________________________________
# lstm_34 (LSTM)               (None, 128)               131584
# _________________________________________________________________
# dense_41 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 64)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 65
# =================================================================
# Total params: 1,714,953
# Trainable params: 1,714,953
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_42 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# lstm_35 (LSTM)               (None, 1000, 128)         219648
# _________________________________________________________________
# lstm_36 (LSTM)               (None, 128)               131584
# _________________________________________________________________
# dense_42 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 128)               0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 129
# =================================================================
# Total params: 1,723,273
# Trainable params: 1,723,273
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_43 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# bidirectional_31 (Bidirectio (None, 1000, 256)         329472
# _________________________________________________________________
# bidirectional_32 (Bidirectio (None, 256)               295680
# _________________________________________________________________
# dense_43 (Dense)             (None, 32)                8224
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 32)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 33
# =================================================================
# Total params: 1,988,809
# Trainable params: 1,988,809
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_44 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# bidirectional_33 (Bidirectio (None, 1000, 256)         329472
# _________________________________________________________________
# bidirectional_34 (Bidirectio (None, 256)               295680
# _________________________________________________________________
# dense_44 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 64)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 65
# =================================================================
# Total params: 1,997,065
# Trainable params: 1,997,065
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_45 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# bidirectional_35 (Bidirectio (None, 1000, 256)         329472
# _________________________________________________________________
# bidirectional_36 (Bidirectio (None, 256)               295680
# _________________________________________________________________
# dense_45 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 128)               0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 129
# =================================================================
# Total params: 2,013,577
# Trainable params: 2,013,577
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_46 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# gru_31 (GRU)                 (None, 1000, 128)         164736
# _________________________________________________________________
# gru_32 (GRU)                 (None, 128)               98688
# _________________________________________________________________
# dense_46 (Dense)             (None, 32)                4128
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 32)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 33
# =================================================================
# Total params: 1,622,985
# Trainable params: 1,622,985
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_47 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# gru_33 (GRU)                 (None, 1000, 128)         164736
# _________________________________________________________________
# gru_34 (GRU)                 (None, 128)               98688
# _________________________________________________________________
# dense_47 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_47 (Dropout)         (None, 64)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 65
# =================================================================
# Total params: 1,627,145
# Trainable params: 1,627,145
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 1000)              0
# _________________________________________________________________
# embedding_48 (Embedding)     (None, 1000, 300)         1355400
# _________________________________________________________________
# gru_35 (GRU)                 (None, 1000, 128)         164736
# _________________________________________________________________
# gru_36 (GRU)                 (None, 128)               98688
# _________________________________________________________________
# dense_48 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_48 (Dropout)         (None, 128)               0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 129
# =================================================================
# Total params: 1,635,465
# Trainable params: 1,635,465
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # TB Colab Callback
# We rewrite the tensorboardcolab callbacks to create different sessions depending on the variables our trainings have. This helps to differentiate the models in tensorboard.

# %%
import os
from keras.callbacks import TensorBoard
import tensorflow as tf

class TensorBoardColabCallback(TensorBoard):
    def __init__(self, tbc=None, write_graph=True, name=None, **kwargs):
        # Make the original `TensorBoard` log to a subdirectory 'training'

        if tbc is None:
            return

        log_dir = tbc.get_graph_path()

        training_log_dir = os.path.join(log_dir, 'training_{}'.format(name))
        super(TensorBoardColabCallback, self).__init__(training_log_dir, **kwargs)

        # Log the validation metrics to a separate subdirectory
        self.val_log_dir = os.path.join(log_dir, 'validation_{}'.format(name))

    def set_model(self, model):
        # Setup writer for validation metrics
        self.val_writer = tf.summary.FileWriter(self.val_log_dir)
        super(TensorBoardColabCallback, self).set_model(model)

    def on_epoch_end(self, epoch, logs=None):
        # Pop the validation logs and handle them separately with
        # `self.val_writer`. Also rename the keys so that they can
        # be plotted on the same figure with the training metrics
        logs = logs or {}
        val_logs = {k.replace('val_', ''): v for k, v in logs.items() if k.startswith('val_')}

        for name, value in val_logs.items():
            # print('val_logs:',epoch, name, value)
            summary = tf.Summary()
            summary_value = summary.value.add()
            summary_value.simple_value = value.item()
            summary_value.tag = name
            self.val_writer.add_summary(summary, epoch)
        self.val_writer.flush()

        # Pass the remaining logs to `TensorBoard.on_epoch_end`
        logs = {k: v for k, v in logs.items() if not k.startswith('val_')}
        super(TensorBoardColabCallback, self).on_epoch_end(epoch, logs)
        
    def on_train_end(self, logs=None):
        super(TensorBoardColabCallback, self).on_train_end(logs)
        self.val_writer.close()

tb.TensorBoardColabCallback = TensorBoardColabCallback

# %%
def define_callbacks(name, tbc=tbc):
  # Define the callbacks
  tbc_callback = tb.TensorBoardColabCallback(tbc, name=name)  # , histogram_freq=1)
   
  callbacks = [
      ReduceLROnPlateau(patience=1),
      EarlyStopping(patience=2),
      tbc_callback
  ]
  return callbacks

# %%
# Create an array of names
network_names = []
for p in network_parameters:
  name = "load_emb_{}_num_classes_{}_emb_size_{}_trainable_emb_{}_cnn_size_{}_cnn_filter_{}_pool_rnn_size_{}_cell_type_{}_bidirectional_{}_attention_{}_dropout_{}_dnn_size_{}_batch_size_{}".format(
      p["load_emb"], p["num_classes"], p["emb_size"], p["trainable_emb"], p["cnn_size"], p["cnn_filter"], p["rnn_size"], 
      str(p["cell_type"]).split(".")[-1].replace("'", "").replace(">", ""), p["bidirectional"],
      p["attention"], p["dropout"], p["dnn_size"], p["batch_size"])
  name = name.replace(" ", "").replace("[", "").replace("]", "").replace(",", "-")
  network_names.append(name)

# %%
from keras.models import load_model
for i, net_model in enumerate(model_list):
  # Set a name for the model based on the tweaked parameters
  p = network_parameters[i]
  name = network_names[i]
  model_path = SST_HOME+"DL/models/B/" + name

  # If the model exists, don't compute it again.
  if os.path.isfile(model_path):
    continue
    
  print("\n\n********************************************\n")    
  print(name)
  callbacks = define_callbacks(name)
  # Fit the model and extract its data
  history = net_model.fit(train_x_token, train_y, epochs=10, batch_size=network_parameters[i]["batch_size"], 
                          callbacks=callbacks, class_weight={0: 0.11, 1: 0.89}, # Classes are weighted proportionally.
                          validation_split=0.25)
      
  # And save the model
  net_model.save(model_path)
  
# To free memory from the gpu
from keras import backend as K
K.clear_session()
# Out:
# ********************************************
#
# load_emb_False_num_classes_1_emb_size_300_trainable_emb_True_cnn_size_None_cnn_filter_3_pool_rnn_size_64-64_cell_type_LSTM_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_1024
# Train on 1140 samples, validate on 380 samples
# W0620 11:21:56.814388 139777107322752 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:850: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# W0620 11:21:56.816132 139777107322752 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:853: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
# Epoch 1/10

# %% [markdown]
# Evaluation
# ========

# %%
for trheshold in np.arange(0.1, 1.1, 0.1):
  print("THRESHOLD: {}\n**********************".format(trheshold))
  from sklearn.metrics import classification_report
  predictions_list = []
  for i, net_model in enumerate(model_list):
    print("\n\n********************************************\n")
    print(network_names[i])
    model_path = SST_HOME+"DL/models/B/" + network_names[i]
    try:
      net_model = load_model(model_path)
    except ValueError:
      print("The model {} was not loaded correctly".format(name))
      continue

    predictions = net_model.predict(test_x_token)
    predictions = np.array([0 if prediction < trheshold else 1 for prediction in predictions])
    predictions_list.append(predictions)
    # measuring performance on test set
    cr=classification_report(test_y, predictions)
    print(cr)
    # Release memory
    K.clear_session()

# %%
from keras.models import load_model
network_names = [""]
for trheshold in np.arange(0.1, 1.1, 0.1):
# trheshold = 0.2
  print("THRESHOLD: {}\n**********************".format(trheshold))
  from sklearn.metrics import classification_report
  predictions_list = []
  i = 0
  network_names[i] = "Copia de load_emb_False_num_classes_1_emb_size_300_trainable_emb_True_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_None"
  
  print(network_names[i])
  model_path = SST_HOME+"DL/models/B/best_models/" + network_names[i]
  try:
    net_model = load_model(model_path)
  except ValueError:
    print("The model {} was not loaded correctly".format(name))
    continue
  except OSError:
    print("The model does not exist")
    continue

  predictions = net_model.predict(test_x_token)
  predictions = np.array([0 if prediction < trheshold else 1 for prediction in predictions])
  predictions_list.append(predictions)
  # measuring performance on test set
  cr=classification_report(test_y, predictions)
  print(cr)
  # Release memory
  K.clear_session()
# Out:
# THRESHOLD: 0.1
# **********************
# Copia de load_emb_False_num_classes_1_emb_size_300_trainable_emb_True_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_None
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      2790
#            1       0.19      0.09      0.12       410
#
#     accuracy                           0.84      3200
#    macro avg       0.53      0.52      0.52      3200
# weighted avg       0.79      0.84      0.81      3200
#
# THRESHOLD: 0.2
# **********************
# Copia de load_emb_False_num_classes_1_emb_size_300_trainable_emb_True_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_None
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.92      2790
#            1       0.17      0.06      0.08       410
#
#     accuracy                           0.84      3200
#    macro avg       0.52      0.51      0.50      3200
# weighted avg       0.78      0.84      0.81      3200
#
# THRESHOLD: 0.30000000000000004
# **********************
# Copia de load_emb_False_num_classes_1_emb_size_300_trainable_emb_True_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_None
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      2790
#            1       0.20      0.06      0.09       410
#
#     accuracy                           0.85      3200
#    macro avg       0.54      0.51      0.50      3200
# weighted avg       0.79      0.85      0.81      3200
#
# THRESHOLD: 0.4
# **********************
# Copia de load_emb_False_num_classes_1_emb_size_300_trainable_emb_True_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_None
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92      2790
#            1       0.23      0.06      0.09       410
#
#     accuracy                           0.85      3200
#    macro avg       0.55      0.51      0.51      3200
# weighted avg       0.79      0.85      0.81      3200
#
# THRESHOLD: 0.5
# **********************
# Copia de load_emb_False_num_classes_1_emb_size_300_trainable_emb_True_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_None
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92      2790
#            1       0.22      0.05      0.08       410
#
#     accuracy                           0.86      3200
#    macro avg       0.55      0.51      0.50      3200
# weighted avg       0.79      0.86      0.81      3200
#
# THRESHOLD: 0.6
# **********************
# Copia de load_emb_False_num_classes_1_emb_size_300_trainable_emb_True_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_None
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92      2790
#            1       0.22      0.04      0.07       410
#
#     accuracy                           0.86      3200
#    macro avg       0.55      0.51      0.50      3200
# weighted avg       0.79      0.86      0.81      3200
#
# THRESHOLD: 0.7000000000000001
# **********************
# Copia de load_emb_False_num_classes_1_emb_size_300_trainable_emb_True_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_None
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.93      2790
#            1       0.26      0.04      0.07       410
#
#     accuracy                           0.86      3200
#    macro avg       0.57      0.51      0.50      3200
# weighted avg       0.80      0.86      0.82      3200
#
# THRESHOLD: 0.8
# **********************
# Copia de load_emb_False_num_classes_1_emb_size_300_trainable_emb_True_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_None
#               precision    recall  f1-score   support
#
#            0       0.87      0.99      0.93      2790
#            1       0.26      0.03      0.05       410
#
#     accuracy                           0.86      3200
#    macro avg       0.56      0.51      0.49      3200
# weighted avg       0.79      0.86      0.82      3200
#
# THRESHOLD: 0.9
# **********************
# Copia de load_emb_False_num_classes_1_emb_size_300_trainable_emb_True_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_None
#               precision    recall  f1-score   support
#
#            0       0.87      0.99      0.93      2790
#            1       0.29      0.02      0.04       410
#
#     accuracy                           0.87      3200
#    macro avg       0.58      0.51      0.48      3200
# weighted avg       0.80      0.87      0.82      3200
#
# THRESHOLD: 1.0
# **********************
# Copia de load_emb_False_num_classes_1_emb_size_300_trainable_emb_True_cnn_size_None_cnn_filter_3_rnn_size_64_cell_type_GRU_bidirectional_True_attention_False_dropout_0.5_dnn_size_32_batch_size_None
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      2790
#            1       0.00      0.00      0.00       410
#
#     accuracy                           0.87      3200
#    macro avg       0.44      0.50      0.47      3200
# weighted avg       0.76      0.87      0.81      3200
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# THRESHOLD: 0.30000000000000004
#
# load_emb_False_num_classes_1_emb_size_300_trainable_emb_True_cnn_size_128_cnn_filter_10_pool_rnn_size_None_cell_type_LSTM_bidirectional_True_attention_False_dropout_0.5_dnn_size_64_batch_size_1024
#               precision    recall  f1-score   support
#
#            0       0.90      0.16      0.26      2790
#            1       0.13      0.88      0.23       410
#
#     accuracy                           0.25      3200
#
#    macro avg       0.52      0.52      0.25      3200
#
#   weighted avg       0.80      0.25      0.26      3200
